# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9416228069143757, score: 32
# Scores: (min: 32, avg: 32, max: 32)
#
# Run: 2, exploration: 0.8265651079747222, score: 27
# Scores: (min: 27, avg: 29.5, max: 32)
#
# Run: 3, exploration: 0.7822236754458713, score: 12
# Scores: (min: 12, avg: 23.666666666666668, max: 32)
#
# Run: 4, exploration: 0.7111635524897149, score: 20
# Scores: (min: 12, avg: 22.75, max: 32)
#
# Run: 5, exploration: 0.6180388156137953, score: 29
# Scores: (min: 12, avg: 24, max: 32)
#
# Run: 6, exploration: 0.5618938591163328, score: 20
# Scores: (min: 12, avg: 23.333333333333332, max: 32)
#
# Run: 7, exploration: 0.531750826943791, score: 12
# Scores: (min: 12, avg: 21.714285714285715, max: 32)
#
# Run: 8, exploration: 0.4858739637363176, score: 19
# Scores: (min: 12, avg: 21.375, max: 32)
#
# Run: 9, exploration: 0.446186062443672, score: 18
# Scores: (min: 12, avg: 21, max: 32)
#
# Run: 10, exploration: 0.42650460709830135, score: 10
# Scores: (min: 10, avg: 19.9, max: 32)
#
# Run: 11, exploration: 0.40974000909221303, score: 9
# Scores: (min: 9, avg: 18.90909090909091, max: 32)
#
# Run: 12, exploration: 0.3897078735047413, score: 11
# Scores: (min: 9, avg: 18.25, max: 32)
#
# Run: 13, exploration: 0.3706551064126331, score: 11
# Scores: (min: 9, avg: 17.692307692307693, max: 32)
#
# Run: 14, exploration: 0.3403786882983606, score: 18
# Scores: (min: 9, avg: 17.714285714285715, max: 32)
#
# Run: 15, exploration: 0.3253644408394192, score: 10
# Scores: (min: 9, avg: 17.2, max: 32)
#
# Run: 16, exploration: 0.31101247816653554, score: 10
# Scores: (min: 9, avg: 16.75, max: 32)
#
# Run: 17, exploration: 0.30028896908517405, score: 8
# Scores: (min: 8, avg: 16.235294117647058, max: 32)
#
# Run: 18, exploration: 0.2827589419554058, score: 13
# Scores: (min: 8, avg: 16.055555555555557, max: 32)
#
# Run: 19, exploration: 0.26759021970270175, score: 12
# Scores: (min: 8, avg: 15.842105263157896, max: 32)
#
# Run: 20, exploration: 0.25578670228422234, score: 10
# Scores: (min: 8, avg: 15.55, max: 32)
#
# Run: 21, exploration: 0.2457325055235537, score: 9
# Scores: (min: 8, avg: 15.238095238095237, max: 32)
#
# Run: 22, exploration: 0.2167901907234072, score: 26
# Scores: (min: 8, avg: 15.727272727272727, max: 32)
#
# Run: 23, exploration: 0.18934890919900021, score: 28
# Scores: (min: 8, avg: 16.26086956521739, max: 32)
#
# Run: 24, exploration: 0.15650920157696743, score: 39
# Scores: (min: 8, avg: 17.208333333333332, max: 39)
#
# Run: 25, exploration: 0.1451730787173275, score: 16
# Scores: (min: 8, avg: 17.16, max: 39)
#
# Run: 26, exploration: 0.12365869841532712, score: 33
# Scores: (min: 8, avg: 17.76923076923077, max: 39)
#
# Run: 27, exploration: 0.11130363979080501, score: 22
# Scores: (min: 8, avg: 17.925925925925927, max: 39)
#
# Run: 28, exploration: 0.1042820154910064, score: 14
# Scores: (min: 8, avg: 17.785714285714285, max: 39)
#
# Run: 29, exploration: 0.07915509187866444, score: 56
# Scores: (min: 8, avg: 19.103448275862068, max: 56)
#
# Run: 30, exploration: 0.06878996970981359, score: 29
# Scores: (min: 8, avg: 19.433333333333334, max: 56)
#
# Run: 31, exploration: 0.06129936495526111, score: 24
# Scores: (min: 8, avg: 19.580645161290324, max: 56)
#
# Run: 32, exploration: 0.058010934765067, score: 12
# Scores: (min: 8, avg: 19.34375, max: 56)
#
# Run: 33, exploration: 0.0543512971290831, score: 14
# Scores: (min: 8, avg: 19.181818181818183, max: 56)
#
# Run: 34, exploration: 0.0451506389749415, score: 38
# Scores: (min: 8, avg: 19.735294117647058, max: 56)
#
# Run: 35, exploration: 0.025754252208694463, score: 113
# Scores: (min: 8, avg: 22.4, max: 113)
#
# Run: 36, exploration: 0.017595559502304726, score: 77
# Scores: (min: 8, avg: 23.916666666666668, max: 113)
#
# Run: 37, exploration: 0.016485538227150154, score: 14
# Scores: (min: 8, avg: 23.64864864864865, max: 113)
#
# Run: 38, exploration: 0.010188702520663827, score: 97
# Scores: (min: 8, avg: 25.57894736842105, max: 113)
#
# Run: 39, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 26.666666666666668, max: 113)
#
# Run: 40, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 28.1, max: 113)
#
# Run: 41, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 29.121951219512194, max: 113)
#
# Run: 42, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 32.666666666666664, max: 178)
#
# Run: 43, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 36.7906976744186, max: 210)
#
# Run: 44, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 39.18181818181818, max: 210)
#
# Run: 45, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 41.044444444444444, max: 210)
#
# Run: 46, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 44.19565217391305, max: 210)
#
# Run: 47, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 44.95744680851064, max: 210)
#
# Run: 48, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 47.208333333333336, max: 210)
#
# Run: 49, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 48.265306122448976, max: 210)
#
# Run: 50, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 49.66, max: 210)
#
# Run: 51, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 51.745098039215684, max: 210)
#
# Run: 52, exploration: 0.01, score: 297
# Scores: (min: 8, avg: 56.46153846153846, max: 297)
#
# Run: 53, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 59.16981132075472, max: 297)
#
# Run: 54, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 61.5, max: 297)
#
# Run: 55, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 63.85454545454545, max: 297)
#
# Run: 56, exploration: 0.01, score: 295
# Scores: (min: 8, avg: 67.98214285714286, max: 297)
#
# Run: 57, exploration: 0.01, score: 424
# Scores: (min: 8, avg: 74.2280701754386, max: 424)
#
# Run: 58, exploration: 0.01, score: 260
# Scores: (min: 8, avg: 77.43103448275862, max: 424)
#
# Run: 59, exploration: 0.01, score: 303
# Scores: (min: 8, avg: 81.2542372881356, max: 424)
#
# Run: 60, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 83.36666666666666, max: 424)
#
# Run: 61, exploration: 0.01, score: 333
# Scores: (min: 8, avg: 87.45901639344262, max: 424)
#
# Run: 62, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 90.19354838709677, max: 424)
#
# Run: 63, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 91.25396825396825, max: 424)
#
# Run: 64, exploration: 0.01, score: 312
# Scores: (min: 8, avg: 94.703125, max: 424)
#
# Run: 65, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 96.35384615384615, max: 424)
#
# Run: 66, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 98.1969696969697, max: 424)
#
# Run: 67, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 99.88059701492537, max: 424)
#
# Run: 68, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 102.08823529411765, max: 424)
#
# Run: 69, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 103.69565217391305, max: 424)
#
# Run: 70, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 105.57142857142857, max: 424)
#
# Run: 71, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 107.01408450704226, max: 424)
#
# Run: 72, exploration: 0.01, score: 317
# Scores: (min: 8, avg: 109.93055555555556, max: 424)
#
# Run: 73, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 110.83561643835617, max: 424)
#
# Run: 74, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 111.9054054054054, max: 424)
#
# Run: 75, exploration: 0.01, score: 268
# Scores: (min: 8, avg: 113.98666666666666, max: 424)
#
# Run: 76, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 114.71052631578948, max: 424)
#
# Run: 77, exploration: 0.01, score: 300
# Scores: (min: 8, avg: 117.11688311688312, max: 424)
#
# Run: 78, exploration: 0.01, score: 298
# Scores: (min: 8, avg: 119.43589743589743, max: 424)
#
# Run: 79, exploration: 0.01, score: 236
# Scores: (min: 8, avg: 120.9113924050633, max: 424)
#
# Run: 80, exploration: 0.01, score: 256
# Scores: (min: 8, avg: 122.6, max: 424)
#
# Run: 81, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 123.55555555555556, max: 424)
#
# Run: 82, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 125, max: 424)
#
# Run: 83, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 125.98795180722891, max: 424)
#
# Run: 84, exploration: 0.01, score: 275
# Scores: (min: 8, avg: 127.76190476190476, max: 424)
#
# Run: 85, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 128.61176470588236, max: 424)
#
# Run: 86, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 129.34883720930233, max: 424)
#
# Run: 87, exploration: 0.01, score: 365
# Scores: (min: 8, avg: 132.05747126436782, max: 424)
#
# Run: 88, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 133.0681818181818, max: 424)
#
# Run: 89, exploration: 0.01, score: 325
# Scores: (min: 8, avg: 135.22471910112358, max: 424)
#
# Run: 90, exploration: 0.01, score: 262
# Scores: (min: 8, avg: 136.63333333333333, max: 424)
#
# Run: 91, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 137.0879120879121, max: 424)
#
# Run: 92, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 137.47826086956522, max: 424)
#
# Run: 93, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 137.98924731182797, max: 424)
#
# Run: 94, exploration: 0.01, score: 443
# Scores: (min: 8, avg: 141.2340425531915, max: 443)
#
# Run: 95, exploration: 0.01, score: 468
# Scores: (min: 8, avg: 144.67368421052632, max: 468)
#
# Run: 96, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 145.5, max: 468)
#
# Run: 97, exploration: 0.01, score: 322
# Scores: (min: 8, avg: 147.31958762886597, max: 468)
#
# Run: 98, exploration: 0.01, score: 274
# Scores: (min: 8, avg: 148.6122448979592, max: 468)
#
# Run: 99, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 149.3030303030303, max: 468)
#
# Run: 100, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 150.85, max: 468)
#
# Run: 101, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 155.53, max: 500)
#
# Run: 102, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 157.28, max: 500)
#
# Run: 103, exploration: 0.01, score: 479
# Scores: (min: 8, avg: 161.95, max: 500)
#
# Run: 104, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 166.75, max: 500)
#
# Run: 105, exploration: 0.01, score: 269
# Scores: (min: 8, avg: 169.15, max: 500)
#
# Run: 106, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 171.36, max: 500)
#
# Run: 107, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 173.09, max: 500)
#
# Run: 108, exploration: 0.01, score: 243
# Scores: (min: 8, avg: 175.33, max: 500)
#
# Run: 109, exploration: 0.01, score: 376
# Scores: (min: 8, avg: 178.91, max: 500)
#
# Run: 110, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 180.66, max: 500)
#
# Run: 111, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 181.95, max: 500)
#
# Run: 112, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 183.95, max: 500)
#
# Run: 113, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 185.37, max: 500)
#
# Run: 114, exploration: 0.01, score: 253
# Scores: (min: 8, avg: 187.72, max: 500)
#
# Run: 115, exploration: 0.01, score: 275
# Scores: (min: 8, avg: 190.37, max: 500)
#
# Run: 116, exploration: 0.01, score: 269
# Scores: (min: 8, avg: 192.96, max: 500)
#
# Run: 117, exploration: 0.01, score: 265
# Scores: (min: 9, avg: 195.53, max: 500)
#
# Solved in 17 runs, 117 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
# Experiment 1: Adjusting Exploration Factor for Quicker Runs
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  

from scores.score_logger import ScoreLogger  

ENV_NAME = "CartPole-v1"

# Parameters
GAMMA = 0.95  
LEARNING_RATE = 0.001  

MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  

# Adjusted Exploration Factor
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.05  # Lower minimum exploration rate
EXPLORATION_DECAY = 0.995  # Faster decay

class DQNSolver:  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  

        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  

    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  

    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  

    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  

def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    max_runs = 500  # Set a maximum number of runs
    while run < max_runs:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()  

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 13
# Scores: (min: 13, avg: 13, max: 13)
#
# Run: 2, exploration: 0.985074875, score: 10
# Scores: (min: 10, avg: 11.5, max: 13)
#
# Run: 3, exploration: 0.8142285204175609, score: 39
# Scores: (min: 10, avg: 20.666666666666668, max: 39)
#
# Run: 4, exploration: 0.7183288830986236, score: 26
# Scores: (min: 10, avg: 22, max: 39)
#
# Run: 5, exploration: 0.6696478204705644, score: 15
# Scores: (min: 10, avg: 20.6, max: 39)
#
# Run: 6, exploration: 0.6088145090359074, score: 20
# Scores: (min: 10, avg: 20.5, max: 39)
#
# Run: 7, exploration: 0.5732736268885887, score: 13
# Scores: (min: 10, avg: 19.428571428571427, max: 39)
#
# Run: 8, exploration: 0.46912134373457726, score: 41
# Scores: (min: 10, avg: 22.125, max: 41)
#
# Run: 9, exploration: 0.32050833588933575, score: 77
# Scores: (min: 10, avg: 28.22222222222222, max: 77)
#
# Run: 10, exploration: 0.2384520680152932, score: 60
# Scores: (min: 10, avg: 31.4, max: 77)
#
# Run: 11, exploration: 0.13001512070402377, score: 122
# Scores: (min: 10, avg: 39.63636363636363, max: 122)
#
# Run: 12, exploration: 0.07196434741762824, score: 119
# Scores: (min: 10, avg: 46.25, max: 122)
#
# Run: 13, exploration: 0.05, score: 119
# Scores: (min: 10, avg: 51.84615384615385, max: 122)
#
# Run: 14, exploration: 0.05, score: 108
# Scores: (min: 10, avg: 55.857142857142854, max: 122)
#
# Run: 15, exploration: 0.05, score: 83
# Scores: (min: 10, avg: 57.666666666666664, max: 122)
#
# Run: 16, exploration: 0.05, score: 199
# Scores: (min: 10, avg: 66.5, max: 199)
#
# Run: 17, exploration: 0.05, score: 130
# Scores: (min: 10, avg: 70.23529411764706, max: 199)
#
# Run: 18, exploration: 0.05, score: 273
# Scores: (min: 10, avg: 81.5, max: 273)
#
# Run: 19, exploration: 0.05, score: 195
# Scores: (min: 10, avg: 87.47368421052632, max: 273)
#
# Run: 20, exploration: 0.05, score: 257
# Scores: (min: 10, avg: 95.95, max: 273)
#
# Run: 21, exploration: 0.05, score: 177
# Scores: (min: 10, avg: 99.80952380952381, max: 273)
#
# Run: 22, exploration: 0.05, score: 449
# Scores: (min: 10, avg: 115.68181818181819, max: 449)
#
# Run: 23, exploration: 0.05, score: 269
# Scores: (min: 10, avg: 122.34782608695652, max: 449)
#
# Run: 24, exploration: 0.05, score: 307
# Scores: (min: 10, avg: 130.04166666666666, max: 449)
#
# Run: 25, exploration: 0.05, score: 200
# Scores: (min: 10, avg: 132.84, max: 449)
#
# Run: 26, exploration: 0.05, score: 262
# Scores: (min: 10, avg: 137.80769230769232, max: 449)
#
# Run: 27, exploration: 0.05, score: 178
# Scores: (min: 10, avg: 139.2962962962963, max: 449)
#
# Run: 28, exploration: 0.05, score: 206
# Scores: (min: 10, avg: 141.67857142857142, max: 449)
#
# Run: 29, exploration: 0.05, score: 191
# Scores: (min: 10, avg: 143.3793103448276, max: 449)
#
# Run: 30, exploration: 0.05, score: 230
# Scores: (min: 10, avg: 146.26666666666668, max: 449)
#
# Run: 31, exploration: 0.05, score: 277
# Scores: (min: 10, avg: 150.48387096774192, max: 449)
#
# Run: 32, exploration: 0.05, score: 258
# Scores: (min: 10, avg: 153.84375, max: 449)
#
# Run: 33, exploration: 0.05, score: 319
# Scores: (min: 10, avg: 158.84848484848484, max: 449)
#
# Run: 34, exploration: 0.05, score: 235
# Scores: (min: 10, avg: 161.08823529411765, max: 449)
#
# Run: 35, exploration: 0.05, score: 182
# Scores: (min: 10, avg: 161.68571428571428, max: 449)
#
# Run: 36, exploration: 0.05, score: 431
# Scores: (min: 10, avg: 169.16666666666666, max: 449)
#
# Run: 37, exploration: 0.05, score: 256
# Scores: (min: 10, avg: 171.51351351351352, max: 449)
#
# Run: 38, exploration: 0.05, score: 241
# Scores: (min: 10, avg: 173.3421052631579, max: 449)
#
# Run: 39, exploration: 0.05, score: 172
# Scores: (min: 10, avg: 173.30769230769232, max: 449)
#
# Run: 40, exploration: 0.05, score: 176
# Scores: (min: 10, avg: 173.375, max: 449)
#
# Run: 41, exploration: 0.05, score: 130
# Scores: (min: 10, avg: 172.3170731707317, max: 449)
#
# Run: 42, exploration: 0.05, score: 289
# Scores: (min: 10, avg: 175.0952380952381, max: 449)
#
# Run: 43, exploration: 0.05, score: 305
# Scores: (min: 10, avg: 178.11627906976744, max: 449)
#
# Run: 44, exploration: 0.05, score: 177
# Scores: (min: 10, avg: 178.0909090909091, max: 449)
#
# Run: 45, exploration: 0.05, score: 320
# Scores: (min: 10, avg: 181.24444444444444, max: 449)
#
# Run: 46, exploration: 0.05, score: 205
# Scores: (min: 10, avg: 181.7608695652174, max: 449)
#
# Run: 47, exploration: 0.05, score: 175
# Scores: (min: 10, avg: 181.61702127659575, max: 449)
#
# Run: 48, exploration: 0.05, score: 460
# Scores: (min: 10, avg: 187.41666666666666, max: 460)
#
# Run: 49, exploration: 0.05, score: 305
# Scores: (min: 10, avg: 189.81632653061226, max: 460)
#
# Run: 50, exploration: 0.05, score: 246
# Scores: (min: 10, avg: 190.94, max: 460)
#
# Run: 51, exploration: 0.05, score: 270
# Scores: (min: 10, avg: 192.49019607843138, max: 460)
#
# Run: 52, exploration: 0.05, score: 207
# Scores: (min: 10, avg: 192.76923076923077, max: 460)
#
# Run: 53, exploration: 0.05, score: 357
# Scores: (min: 10, avg: 195.8679245283019, max: 460)
#
# Run: 54, exploration: 0.05, score: 198
# Scores: (min: 10, avg: 195.90740740740742, max: 460)
#
# Run: 55, exploration: 0.05, score: 177
# Scores: (min: 10, avg: 195.56363636363636, max: 460)
#
# Run: 56, exploration: 0.05, score: 129
# Scores: (min: 10, avg: 194.375, max: 460)
#
# Run: 57, exploration: 0.05, score: 206
# Scores: (min: 10, avg: 194.57894736842104, max: 460)
#
# Run: 58, exploration: 0.05, score: 222
# Scores: (min: 10, avg: 195.05172413793105, max: 460)
#
# Run: 59, exploration: 0.05, score: 214
# Scores: (min: 10, avg: 195.3728813559322, max: 460)
#
# Run: 60, exploration: 0.05, score: 192
# Scores: (min: 10, avg: 195.31666666666666, max: 460)
#
# Run: 61, exploration: 0.05, score: 154
# Scores: (min: 10, avg: 194.63934426229508, max: 460)
#
# Run: 62, exploration: 0.05, score: 227
# Scores: (min: 10, avg: 195.16129032258064, max: 460)
#
# Run: 63, exploration: 0.05, score: 180
# Scores: (min: 10, avg: 194.9206349206349, max: 460)
#
# Run: 64, exploration: 0.05, score: 207
# Scores: (min: 10, avg: 195.109375, max: 460)
#
# Run: 65, exploration: 0.05, score: 170
# Scores: (min: 10, avg: 194.72307692307692, max: 460)
#
# Run: 66, exploration: 0.05, score: 177
# Scores: (min: 10, avg: 194.45454545454547, max: 460)
#
# Run: 67, exploration: 0.05, score: 200
# Scores: (min: 10, avg: 194.53731343283582, max: 460)
#
# Run: 68, exploration: 0.05, score: 27
# Scores: (min: 10, avg: 192.0735294117647, max: 460)
#
# Run: 69, exploration: 0.05, score: 137
# Scores: (min: 10, avg: 191.2753623188406, max: 460)
#
# Run: 70, exploration: 0.05, score: 283
# Scores: (min: 10, avg: 192.5857142857143, max: 460)
#
# Run: 71, exploration: 0.05, score: 314
# Scores: (min: 10, avg: 194.29577464788733, max: 460)
#
# Run: 72, exploration: 0.05, score: 83
# Scores: (min: 10, avg: 192.75, max: 460)
#
# Run: 73, exploration: 0.05, score: 142
# Scores: (min: 10, avg: 192.05479452054794, max: 460)
#
# Run: 74, exploration: 0.05, score: 290
# Scores: (min: 10, avg: 193.3783783783784, max: 460)
#
# Run: 75, exploration: 0.05, score: 171
# Scores: (min: 10, avg: 193.08, max: 460)
#
# Run: 76, exploration: 0.05, score: 235
# Scores: (min: 10, avg: 193.6315789473684, max: 460)
#
# Run: 77, exploration: 0.05, score: 206
# Scores: (min: 10, avg: 193.7922077922078, max: 460)
#
# Run: 78, exploration: 0.05, score: 188
# Scores: (min: 10, avg: 193.71794871794873, max: 460)
#
# Run: 79, exploration: 0.05, score: 260
# Scores: (min: 10, avg: 194.55696202531647, max: 460)
#
# Run: 80, exploration: 0.05, score: 178
# Scores: (min: 10, avg: 194.35, max: 460)
#
# Run: 81, exploration: 0.05, score: 356
# Scores: (min: 10, avg: 196.34567901234567, max: 460)
#
# Run: 82, exploration: 0.05, score: 257
# Scores: (min: 10, avg: 197.08536585365854, max: 460)
#
# Run: 83, exploration: 0.05, score: 189
# Scores: (min: 10, avg: 196.9879518072289, max: 460)
#
# Run: 84, exploration: 0.05, score: 401
# Scores: (min: 10, avg: 199.41666666666666, max: 460)
#
# Run: 85, exploration: 0.05, score: 235
# Scores: (min: 10, avg: 199.83529411764707, max: 460)
#
# Run: 86, exploration: 0.05, score: 341
# Scores: (min: 10, avg: 201.47674418604652, max: 460)
#
# Run: 87, exploration: 0.05, score: 238
# Scores: (min: 10, avg: 201.89655172413794, max: 460)
#
# Run: 88, exploration: 0.05, score: 402
# Scores: (min: 10, avg: 204.17045454545453, max: 460)
#
# Run: 89, exploration: 0.05, score: 172
# Scores: (min: 10, avg: 203.80898876404495, max: 460)
#
# Run: 90, exploration: 0.05, score: 330
# Scores: (min: 10, avg: 205.2111111111111, max: 460)
#
# Run: 91, exploration: 0.05, score: 215
# Scores: (min: 10, avg: 205.3186813186813, max: 460)
#
# Run: 92, exploration: 0.05, score: 297
# Scores: (min: 10, avg: 206.31521739130434, max: 460)
#
# Run: 93, exploration: 0.05, score: 251
# Scores: (min: 10, avg: 206.79569892473117, max: 460)
#
# Run: 94, exploration: 0.05, score: 208
# Scores: (min: 10, avg: 206.80851063829786, max: 460)
#
# Run: 95, exploration: 0.05, score: 149
# Scores: (min: 10, avg: 206.2, max: 460)
#
# Run: 96, exploration: 0.05, score: 141
# Scores: (min: 10, avg: 205.52083333333334, max: 460)
#
# Run: 97, exploration: 0.05, score: 266
# Scores: (min: 10, avg: 206.1443298969072, max: 460)
#
# Run: 98, exploration: 0.05, score: 178
# Scores: (min: 10, avg: 205.85714285714286, max: 460)
#
# Run: 99, exploration: 0.05, score: 186
# Scores: (min: 10, avg: 205.65656565656565, max: 460)
#
# Run: 100, exploration: 0.05, score: 245
# Scores: (min: 10, avg: 206.05, max: 460)
#
# Solved in 0 runs, 100 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fb96a2cd61c8> in <module>
#      86             dqn_solver.experience_replay()
#      87
# ---> 88 cartpole()
#
# <ipython-input-5-fb96a2cd61c8> in cartpole()
#      82             if terminal:
#      83                 print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 84                 score_logger.add_score(step, run)
#      85                 break
#      86             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
# Experiment 2: Adjusting Discount Factor with Baseline Values
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  

from scores.score_logger import ScoreLogger  

ENV_NAME = "CartPole-v1"

# Parameters (Baseline values except for GAMMA)
GAMMA = 0.85  # Lower discount factor to prioritize immediate rewards
LEARNING_RATE = 0.001  # Baseline learning rate

MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  

# Exploration Parameters (Baseline values)
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  

class DQNSolver:  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  

        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  

    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  

    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  

    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  

def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    max_runs = 500  # Set a maximum number of runs to limit execution time
    while run < max_runs:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()  

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.9229311239742362, score: 19
# Scores: (min: 17, avg: 18, max: 19)
#
# Run: 3, exploration: 0.8265651079747222, score: 23
# Scores: (min: 17, avg: 19.666666666666668, max: 23)
#
# Run: 4, exploration: 0.7255664080186093, score: 27
# Scores: (min: 17, avg: 21.5, max: 27)
#
# Run: 5, exploration: 0.6211445383053219, score: 32
# Scores: (min: 17, avg: 23.6, max: 32)
#
# Run: 6, exploration: 0.43952667968844233, score: 70
# Scores: (min: 17, avg: 31.333333333333332, max: 70)
#
# Run: 7, exploration: 0.3669578217261671, score: 37
# Scores: (min: 17, avg: 32.142857142857146, max: 70)
#
# Run: 8, exploration: 0.28417984116121187, score: 52
# Scores: (min: 17, avg: 34.625, max: 70)
#
# Run: 9, exploration: 0.20931540516921554, score: 62
# Scores: (min: 17, avg: 37.666666666666664, max: 70)
#
# Run: 10, exploration: 0.09770335251664321, score: 153
# Scores: (min: 17, avg: 49.2, max: 153)
#
# Run: 11, exploration: 0.027488364100186506, score: 254
# Scores: (min: 17, avg: 67.81818181818181, max: 254)
#
# Run: 12, exploration: 0.01, score: 275
# Scores: (min: 17, avg: 85.08333333333333, max: 275)
#
# Run: 13, exploration: 0.01, score: 264
# Scores: (min: 17, avg: 98.84615384615384, max: 275)
#
# Run: 14, exploration: 0.01, score: 252
# Scores: (min: 17, avg: 109.78571428571429, max: 275)
#
# Run: 15, exploration: 0.01, score: 303
# Scores: (min: 17, avg: 122.66666666666667, max: 303)
#
# Run: 16, exploration: 0.01, score: 187
# Scores: (min: 17, avg: 126.6875, max: 303)
#
# Run: 17, exploration: 0.01, score: 265
# Scores: (min: 17, avg: 134.8235294117647, max: 303)
#
# Run: 18, exploration: 0.01, score: 73
# Scores: (min: 17, avg: 131.38888888888889, max: 303)
#
# Run: 19, exploration: 0.01, score: 325
# Scores: (min: 17, avg: 141.57894736842104, max: 325)
#
# Run: 20, exploration: 0.01, score: 210
# Scores: (min: 17, avg: 145, max: 325)
#
# Run: 21, exploration: 0.01, score: 83
# Scores: (min: 17, avg: 142.04761904761904, max: 325)
#
# Run: 22, exploration: 0.01, score: 107
# Scores: (min: 17, avg: 140.45454545454547, max: 325)
#
# Run: 23, exploration: 0.01, score: 156
# Scores: (min: 17, avg: 141.1304347826087, max: 325)
#
# Run: 24, exploration: 0.01, score: 260
# Scores: (min: 17, avg: 146.08333333333334, max: 325)
#
# Run: 25, exploration: 0.01, score: 143
# Scores: (min: 17, avg: 145.96, max: 325)
#
# Run: 26, exploration: 0.01, score: 500
# Scores: (min: 17, avg: 159.57692307692307, max: 500)
#
# Run: 27, exploration: 0.01, score: 37
# Scores: (min: 17, avg: 155.03703703703704, max: 500)
#
# Run: 28, exploration: 0.01, score: 31
# Scores: (min: 17, avg: 150.60714285714286, max: 500)
#
# Run: 29, exploration: 0.01, score: 500
# Scores: (min: 17, avg: 162.6551724137931, max: 500)
#
# Run: 30, exploration: 0.01, score: 500
# Scores: (min: 17, avg: 173.9, max: 500)
#
# Run: 31, exploration: 0.01, score: 453
# Scores: (min: 17, avg: 182.90322580645162, max: 500)
#
# Run: 32, exploration: 0.01, score: 233
# Scores: (min: 17, avg: 184.46875, max: 500)
#
# Run: 33, exploration: 0.01, score: 100
# Scores: (min: 17, avg: 181.9090909090909, max: 500)
#
# Run: 34, exploration: 0.01, score: 135
# Scores: (min: 17, avg: 180.52941176470588, max: 500)
#
# Run: 35, exploration: 0.01, score: 400
# Scores: (min: 17, avg: 186.8, max: 500)
#
# Run: 36, exploration: 0.01, score: 226
# Scores: (min: 17, avg: 187.88888888888889, max: 500)
#
# Run: 37, exploration: 0.01, score: 395
# Scores: (min: 17, avg: 193.48648648648648, max: 500)
#
# Run: 38, exploration: 0.01, score: 170
# Scores: (min: 17, avg: 192.8684210526316, max: 500)
#
# Run: 39, exploration: 0.01, score: 65
# Scores: (min: 17, avg: 189.5897435897436, max: 500)
#
# Run: 40, exploration: 0.01, score: 148
# Scores: (min: 17, avg: 188.55, max: 500)
#
# Run: 41, exploration: 0.01, score: 276
# Scores: (min: 17, avg: 190.6829268292683, max: 500)
#
# Run: 42, exploration: 0.01, score: 320
# Scores: (min: 17, avg: 193.76190476190476, max: 500)
#
# Run: 43, exploration: 0.01, score: 258
# Scores: (min: 17, avg: 195.25581395348837, max: 500)
#
# Run: 44, exploration: 0.01, score: 156
# Scores: (min: 17, avg: 194.36363636363637, max: 500)
#
# Run: 45, exploration: 0.01, score: 344
# Scores: (min: 17, avg: 197.6888888888889, max: 500)
#
# Run: 46, exploration: 0.01, score: 202
# Scores: (min: 17, avg: 197.7826086956522, max: 500)
#
# Run: 47, exploration: 0.01, score: 275
# Scores: (min: 17, avg: 199.4255319148936, max: 500)
#
# Run: 48, exploration: 0.01, score: 200
# Scores: (min: 17, avg: 199.4375, max: 500)
#
# Run: 49, exploration: 0.01, score: 222
# Scores: (min: 17, avg: 199.89795918367346, max: 500)
#
# Run: 50, exploration: 0.01, score: 310
# Scores: (min: 17, avg: 202.1, max: 500)
#
# Run: 51, exploration: 0.01, score: 500
# Scores: (min: 17, avg: 207.94117647058823, max: 500)
#
# Run: 52, exploration: 0.01, score: 117
# Scores: (min: 17, avg: 206.19230769230768, max: 500)
#
# Run: 53, exploration: 0.01, score: 215
# Scores: (min: 17, avg: 206.35849056603774, max: 500)
#
# Run: 54, exploration: 0.01, score: 215
# Scores: (min: 17, avg: 206.5185185185185, max: 500)
#
# Run: 55, exploration: 0.01, score: 299
# Scores: (min: 17, avg: 208.2, max: 500)
#
# Run: 56, exploration: 0.01, score: 293
# Scores: (min: 17, avg: 209.71428571428572, max: 500)
#
# Run: 57, exploration: 0.01, score: 189
# Scores: (min: 17, avg: 209.35087719298247, max: 500)
#
# Run: 58, exploration: 0.01, score: 294
# Scores: (min: 17, avg: 210.81034482758622, max: 500)
#
# Run: 59, exploration: 0.01, score: 134
# Scores: (min: 17, avg: 209.5084745762712, max: 500)
#
# Run: 60, exploration: 0.01, score: 124
# Scores: (min: 17, avg: 208.08333333333334, max: 500)
#
# Run: 61, exploration: 0.01, score: 179
# Scores: (min: 17, avg: 207.60655737704917, max: 500)
#
# Run: 62, exploration: 0.01, score: 345
# Scores: (min: 17, avg: 209.82258064516128, max: 500)
#
# Run: 63, exploration: 0.01, score: 180
# Scores: (min: 17, avg: 209.34920634920636, max: 500)
#
# Run: 64, exploration: 0.01, score: 134
# Scores: (min: 17, avg: 208.171875, max: 500)
#
# Run: 65, exploration: 0.01, score: 53
# Scores: (min: 17, avg: 205.7846153846154, max: 500)
#
# Run: 66, exploration: 0.01, score: 129
# Scores: (min: 17, avg: 204.62121212121212, max: 500)
#
# Run: 67, exploration: 0.01, score: 165
# Scores: (min: 17, avg: 204.02985074626866, max: 500)
#
# Run: 68, exploration: 0.01, score: 83
# Scores: (min: 17, avg: 202.25, max: 500)
#
# Run: 69, exploration: 0.01, score: 118
# Scores: (min: 17, avg: 201.02898550724638, max: 500)
#
# Run: 70, exploration: 0.01, score: 141
# Scores: (min: 17, avg: 200.17142857142858, max: 500)
#
# Run: 71, exploration: 0.01, score: 107
# Scores: (min: 17, avg: 198.85915492957747, max: 500)
#
# Run: 72, exploration: 0.01, score: 274
# Scores: (min: 17, avg: 199.90277777777777, max: 500)
#
# Run: 73, exploration: 0.01, score: 161
# Scores: (min: 17, avg: 199.36986301369862, max: 500)
#
# Run: 74, exploration: 0.01, score: 121
# Scores: (min: 17, avg: 198.3108108108108, max: 500)
#
# Run: 75, exploration: 0.01, score: 177
# Scores: (min: 17, avg: 198.02666666666667, max: 500)
#
# Run: 76, exploration: 0.01, score: 107
# Scores: (min: 17, avg: 196.82894736842104, max: 500)
#
# Run: 77, exploration: 0.01, score: 151
# Scores: (min: 17, avg: 196.23376623376623, max: 500)
#
# Run: 78, exploration: 0.01, score: 117
# Scores: (min: 17, avg: 195.21794871794873, max: 500)
#
# Run: 79, exploration: 0.01, score: 119
# Scores: (min: 17, avg: 194.25316455696202, max: 500)
#
# Run: 80, exploration: 0.01, score: 181
# Scores: (min: 17, avg: 194.0875, max: 500)
#
# Run: 81, exploration: 0.01, score: 200
# Scores: (min: 17, avg: 194.1604938271605, max: 500)
#
# Run: 82, exploration: 0.01, score: 152
# Scores: (min: 17, avg: 193.64634146341464, max: 500)
#
# Run: 83, exploration: 0.01, score: 212
# Scores: (min: 17, avg: 193.86746987951807, max: 500)
#
# Run: 84, exploration: 0.01, score: 21
# Scores: (min: 17, avg: 191.8095238095238, max: 500)
#
# Run: 85, exploration: 0.01, score: 78
# Scores: (min: 17, avg: 190.47058823529412, max: 500)
#
# Run: 86, exploration: 0.01, score: 105
# Scores: (min: 17, avg: 189.47674418604652, max: 500)
#
# Run: 87, exploration: 0.01, score: 103
# Scores: (min: 17, avg: 188.48275862068965, max: 500)
#
# Run: 88, exploration: 0.01, score: 149
# Scores: (min: 17, avg: 188.0340909090909, max: 500)
#
# Run: 89, exploration: 0.01, score: 83
# Scores: (min: 17, avg: 186.85393258426967, max: 500)
#
# Run: 90, exploration: 0.01, score: 123
# Scores: (min: 17, avg: 186.14444444444445, max: 500)
#
# Run: 91, exploration: 0.01, score: 76
# Scores: (min: 17, avg: 184.93406593406593, max: 500)
#
# Run: 92, exploration: 0.01, score: 97
# Scores: (min: 17, avg: 183.97826086956522, max: 500)
#
# Run: 93, exploration: 0.01, score: 103
# Scores: (min: 17, avg: 183.10752688172042, max: 500)
#
# Run: 94, exploration: 0.01, score: 110
# Scores: (min: 17, avg: 182.32978723404256, max: 500)
#
# Run: 95, exploration: 0.01, score: 86
# Scores: (min: 17, avg: 181.31578947368422, max: 500)
#
# Run: 96, exploration: 0.01, score: 150
# Scores: (min: 17, avg: 180.98958333333334, max: 500)
#
# Run: 97, exploration: 0.01, score: 121
# Scores: (min: 17, avg: 180.37113402061857, max: 500)
#
# Run: 98, exploration: 0.01, score: 132
# Scores: (min: 17, avg: 179.87755102040816, max: 500)
#
# Run: 99, exploration: 0.01, score: 155
# Scores: (min: 17, avg: 179.62626262626262, max: 500)
#
# Run: 100, exploration: 0.01, score: 352
# Scores: (min: 17, avg: 181.35, max: 500)
#
# Run: 101, exploration: 0.01, score: 46
# Scores: (min: 19, avg: 181.64, max: 500)
#
# Run: 102, exploration: 0.01, score: 32
# Scores: (min: 21, avg: 181.77, max: 500)
#
# Run: 103, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 181.64, max: 500)
#
# Run: 104, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 182.45, max: 500)
#
# Run: 105, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 183.49, max: 500)
#
# Run: 106, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 183.81, max: 500)
#
# Run: 107, exploration: 0.01, score: 231
# Scores: (min: 10, avg: 185.75, max: 500)
#
# Run: 108, exploration: 0.01, score: 242
# Scores: (min: 10, avg: 187.65, max: 500)
#
# Run: 109, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 188.45, max: 500)
#
# Run: 110, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 187.87, max: 500)
#
# Run: 111, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 186.83, max: 500)
#
# Run: 112, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 185.59, max: 500)
#
# Run: 113, exploration: 0.01, score: 185
# Scores: (min: 10, avg: 184.8, max: 500)
#
# Run: 114, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 183.61, max: 500)
#
# Run: 115, exploration: 0.01, score: 215
# Scores: (min: 10, avg: 182.73, max: 500)
#
# Run: 116, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 182.28, max: 500)
#
# Run: 117, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 180.7, max: 500)
#
# Run: 118, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 181.96, max: 500)
#
# Run: 119, exploration: 0.01, score: 158
# Scores: (min: 10, avg: 180.29, max: 500)
#
# Run: 120, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 179.51, max: 500)
#
# Run: 121, exploration: 0.01, score: 76
# Scores: (min: 10, avg: 179.44, max: 500)
#
# Run: 122, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 180.27, max: 500)
#
# Run: 123, exploration: 0.01, score: 106
# Scores: (min: 10, avg: 179.77, max: 500)
#
# Run: 124, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 178.2, max: 500)
#
# Run: 125, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 177.86, max: 500)
#
# Run: 126, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 173.91, max: 500)
#
# Run: 127, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 174.55, max: 500)
#
# Run: 128, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 175.36, max: 500)
#
# Run: 129, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 172.16, max: 500)
#
# Run: 130, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 168.48, max: 500)
#
# Run: 131, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 165.47, max: 500)
#
# Run: 132, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 164.06, max: 500)
#
# Run: 133, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 164.88, max: 500)
#
# Run: 134, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 164.63, max: 500)
#
# Run: 135, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 161.61, max: 500)
#
# Run: 136, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 160.67, max: 500)
#
# Run: 137, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 158.09, max: 500)
#
# Run: 138, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 157.36, max: 500)
#
# Run: 139, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 157.64, max: 500)
#
# Run: 140, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 157.37, max: 500)
#
# Run: 141, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 155.81, max: 500)
#
# Run: 142, exploration: 0.01, score: 353
# Scores: (min: 10, avg: 156.14, max: 500)
#
# Run: 143, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 154.46, max: 500)
#
# Run: 144, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 153.8, max: 500)
#
# Run: 145, exploration: 0.01, score: 248
# Scores: (min: 10, avg: 152.84, max: 500)
#
# Run: 146, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 151.75, max: 500)
#
# Run: 147, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 149.57, max: 500)
#
# Run: 148, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 149.58, max: 500)
#
# Run: 149, exploration: 0.01, score: 234
# Scores: (min: 10, avg: 149.7, max: 500)
#
# Run: 150, exploration: 0.01, score: 186
# Scores: (min: 10, avg: 148.46, max: 500)
#
# Run: 151, exploration: 0.01, score: 418
# Scores: (min: 10, avg: 147.64, max: 418)
#
# Run: 152, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 147.95, max: 418)
#
# Run: 153, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 147, max: 418)
#
# Run: 154, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 146.69, max: 418)
#
# Run: 155, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 145.11, max: 418)
#
# Run: 156, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 143.69, max: 418)
#
# Run: 157, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 143.9, max: 418)
#
# Run: 158, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 142.18, max: 418)
#
# Run: 159, exploration: 0.01, score: 196
# Scores: (min: 10, avg: 142.8, max: 418)
#
# Run: 160, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 143.47, max: 418)
#
# Run: 161, exploration: 0.01, score: 86
# Scores: (min: 10, avg: 142.54, max: 418)
#
# Run: 162, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 140.27, max: 418)
#
# Run: 163, exploration: 0.01, score: 221
# Scores: (min: 10, avg: 140.68, max: 418)
#
# Run: 164, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 140.74, max: 418)
#
# Run: 165, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 141.64, max: 418)
#
# Run: 166, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 142.01, max: 418)
#
# Run: 167, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 140.59, max: 418)
#
# Run: 168, exploration: 0.01, score: 258
# Scores: (min: 10, avg: 142.34, max: 418)
#
# Run: 169, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 142.82, max: 418)
#
# Run: 170, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 142.05, max: 418)
#
# Run: 171, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 142.37, max: 418)
#
# Run: 172, exploration: 0.01, score: 328
# Scores: (min: 10, avg: 142.91, max: 418)
#
# Run: 173, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 142.94, max: 418)
#
# Run: 174, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 143.08, max: 418)
#
# Run: 175, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 142.55, max: 418)
#
# Run: 176, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 143.29, max: 418)
#
# Run: 177, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 142.73, max: 418)
#
# Run: 178, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 142.65, max: 418)
#
# Run: 179, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 141.65, max: 418)
#
# Run: 180, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 140.74, max: 418)
#
# Run: 181, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 139.86, max: 418)
#
# Run: 182, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 139.72, max: 418)
#
# Run: 183, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 138.6, max: 418)
#
# Run: 184, exploration: 0.01, score: 291
# Scores: (min: 10, avg: 141.3, max: 418)
#
# Run: 185, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 141.51, max: 418)
#
# Run: 186, exploration: 0.01, score: 49
# Scores: (min: 10, avg: 140.95, max: 418)
#
# Run: 187, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 141.06, max: 418)
#
# Run: 188, exploration: 0.01, score: 194
# Scores: (min: 10, avg: 141.51, max: 418)
#
# Run: 189, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 141.68, max: 418)
#
# Run: 190, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 142.61, max: 418)
#
# Run: 191, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 143.28, max: 418)
#
# Run: 192, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 142.56, max: 418)
#
# Run: 193, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 142.58, max: 418)
#
# Run: 194, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 142.75, max: 418)
#
# Run: 195, exploration: 0.01, score: 55
# Scores: (min: 10, avg: 142.44, max: 418)
#
# Run: 196, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 141.75, max: 418)
#
# Run: 197, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 140.79, max: 418)
#
# Run: 198, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 140.51, max: 418)
#
# Run: 199, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 140.42, max: 418)
#
# Run: 200, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 137.87, max: 418)
#
# Run: 201, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 137.94, max: 418)
#
# Run: 202, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 139.49, max: 418)
#
# Run: 203, exploration: 0.01, score: 95
# Scores: (min: 19, avg: 140.34, max: 418)
#
# Run: 204, exploration: 0.01, score: 117
# Scores: (min: 19, avg: 140.43, max: 418)
#
# Run: 205, exploration: 0.01, score: 132
# Scores: (min: 19, avg: 140.39, max: 418)
#
# Run: 206, exploration: 0.01, score: 186
# Scores: (min: 19, avg: 141.23, max: 418)
#
# Run: 207, exploration: 0.01, score: 105
# Scores: (min: 19, avg: 139.97, max: 418)
#
# Run: 208, exploration: 0.01, score: 96
# Scores: (min: 19, avg: 138.51, max: 418)
#
# Run: 209, exploration: 0.01, score: 106
# Scores: (min: 19, avg: 138.15, max: 418)
#
# Run: 210, exploration: 0.01, score: 134
# Scores: (min: 19, avg: 138.54, max: 418)
#
# Run: 211, exploration: 0.01, score: 36
# Scores: (min: 19, avg: 137.4, max: 418)
#
# Run: 212, exploration: 0.01, score: 208
# Scores: (min: 19, avg: 137.97, max: 418)
#
# Run: 213, exploration: 0.01, score: 19
# Scores: (min: 19, avg: 136.31, max: 418)
#
# Run: 214, exploration: 0.01, score: 135
# Scores: (min: 19, avg: 136.33, max: 418)
#
# Run: 215, exploration: 0.01, score: 73
# Scores: (min: 19, avg: 134.91, max: 418)
#
# Run: 216, exploration: 0.01, score: 93
# Scores: (min: 19, avg: 134.42, max: 418)
#
# Run: 217, exploration: 0.01, score: 28
# Scores: (min: 19, avg: 133.63, max: 418)
#
# Run: 218, exploration: 0.01, score: 129
# Scores: (min: 19, avg: 132.93, max: 418)
#
# Run: 219, exploration: 0.01, score: 93
# Scores: (min: 19, avg: 132.28, max: 418)
#
# Run: 220, exploration: 0.01, score: 120
# Scores: (min: 19, avg: 132.16, max: 418)
#
# Run: 221, exploration: 0.01, score: 111
# Scores: (min: 19, avg: 132.51, max: 418)
#
# Run: 222, exploration: 0.01, score: 66
# Scores: (min: 19, avg: 131.27, max: 418)
#
# Run: 223, exploration: 0.01, score: 95
# Scores: (min: 19, avg: 131.16, max: 418)
#
# Run: 224, exploration: 0.01, score: 77
# Scores: (min: 19, avg: 130.9, max: 418)
#
# Run: 225, exploration: 0.01, score: 136
# Scores: (min: 19, avg: 131.17, max: 418)
#
# Run: 226, exploration: 0.01, score: 112
# Scores: (min: 19, avg: 131.24, max: 418)
#
# Run: 227, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 130.34, max: 418)
#
# Run: 228, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 129.63, max: 418)
#
# Run: 229, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 127.96, max: 418)
#
# Run: 230, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 127.88, max: 418)
#
# Run: 231, exploration: 0.01, score: 110
# Scores: (min: 11, avg: 127.46, max: 418)
#
# Run: 232, exploration: 0.01, score: 225
# Scores: (min: 11, avg: 128.79, max: 418)
#
# Run: 233, exploration: 0.01, score: 88
# Scores: (min: 11, avg: 127.85, max: 418)
#
# Run: 234, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 128.39, max: 418)
#
# Run: 235, exploration: 0.01, score: 90
# Scores: (min: 11, avg: 128.31, max: 418)
#
# Run: 236, exploration: 0.01, score: 172
# Scores: (min: 11, avg: 128.71, max: 418)
#
# Run: 237, exploration: 0.01, score: 322
# Scores: (min: 11, avg: 130.56, max: 418)
#
# Run: 238, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 129.69, max: 418)
#
# Run: 239, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 128.92, max: 418)
#
# Run: 240, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 127.9, max: 418)
#
# Run: 241, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 127.78, max: 418)
#
# Run: 242, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 125.32, max: 418)
#
# Run: 243, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 126.03, max: 418)
#
# Run: 244, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 125.35, max: 418)
#
# Run: 245, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 123, max: 418)
#
# Run: 246, exploration: 0.01, score: 84
# Scores: (min: 10, avg: 122.91, max: 418)
#
# Run: 247, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 122.49, max: 418)
#
# Run: 248, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 120.66, max: 418)
#
# Run: 249, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 119.01, max: 418)
#
# Run: 250, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 117.26, max: 418)
#
# Run: 251, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 113.22, max: 328)
#
# Run: 252, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 112.75, max: 328)
#
# Run: 253, exploration: 0.01, score: 115
# Scores: (min: 10, avg: 112.7, max: 328)
#
# Run: 254, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 111.63, max: 328)
#
# Run: 255, exploration: 0.01, score: 63
# Scores: (min: 10, avg: 110.85, max: 328)
#
# Run: 256, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 111.16, max: 328)
#
# Run: 257, exploration: 0.01, score: 71
# Scores: (min: 10, avg: 109.77, max: 328)
#
# Run: 258, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 108.66, max: 328)
#
# Run: 259, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 107.47, max: 328)
#
# Run: 260, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 107.12, max: 328)
#
# Run: 261, exploration: 0.01, score: 389
# Scores: (min: 10, avg: 110.15, max: 389)
#
# Run: 262, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 109.85, max: 389)
#
# Run: 263, exploration: 0.01, score: 111
# Scores: (min: 10, avg: 108.75, max: 389)
#
# Run: 264, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 107.56, max: 389)
#
# Run: 265, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 106.4, max: 389)
#
# Run: 266, exploration: 0.01, score: 70
# Scores: (min: 10, avg: 105.44, max: 389)
#
# Run: 267, exploration: 0.01, score: 314
# Scores: (min: 10, avg: 108.35, max: 389)
#
# Run: 268, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 106.95, max: 389)
#
# Run: 269, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 105.67, max: 389)
#
# Run: 270, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 106.24, max: 389)
#
# Run: 271, exploration: 0.01, score: 235
# Scores: (min: 10, avg: 107.2, max: 389)
#
# Run: 272, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 104.59, max: 389)
#
# Run: 273, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 103.35, max: 389)
#
# Run: 274, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 102.9, max: 389)
#
# Run: 275, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 102.23, max: 389)
#
# Run: 276, exploration: 0.01, score: 65
# Scores: (min: 10, avg: 101.07, max: 389)
#
# Run: 277, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 100.81, max: 389)
#
# Run: 278, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 100.11, max: 389)
#
# Run: 279, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 100.35, max: 389)
#
# Run: 280, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 99.58, max: 389)
#
# Run: 281, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 99.54, max: 389)
#
# Run: 282, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 99.04, max: 389)
#
# Run: 283, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 99.05, max: 389)
#
# Run: 284, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 97.47, max: 389)
#
# Run: 285, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 97.5, max: 389)
#
# Run: 286, exploration: 0.01, score: 59
# Scores: (min: 10, avg: 97.6, max: 389)
#
# Run: 287, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 96.57, max: 389)
#
# Run: 288, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 94.76, max: 389)
#
# Run: 289, exploration: 0.01, score: 189
# Scores: (min: 10, avg: 95.65, max: 389)
#
# Run: 290, exploration: 0.01, score: 188
# Scores: (min: 10, avg: 95.37, max: 389)
#
# Run: 291, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 94.96, max: 389)
#
# Run: 292, exploration: 0.01, score: 197
# Scores: (min: 10, avg: 96.68, max: 389)
#
# Run: 293, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 96.01, max: 389)
#
# Run: 294, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 96.9, max: 389)
#
# Run: 295, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 96.76, max: 389)
#
# Run: 296, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 96.18, max: 389)
#
# Run: 297, exploration: 0.01, score: 45
# Scores: (min: 10, avg: 96.38, max: 389)
#
# Run: 298, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 97.04, max: 389)
#
# Run: 299, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 97.12, max: 389)
#
# Run: 300, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 97.09, max: 389)
#
# Run: 301, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 96.91, max: 389)
#
# Run: 302, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 95.27, max: 389)
#
# Run: 303, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 95.11, max: 389)
#
# Run: 304, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 95.25, max: 389)
#
# Run: 305, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 94.62, max: 389)
#
# Run: 306, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 93.77, max: 389)
#
# Run: 307, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 94.03, max: 389)
#
# Run: 308, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 94.43, max: 389)
#
# Run: 309, exploration: 0.01, score: 241
# Scores: (min: 10, avg: 95.78, max: 389)
#
# Run: 310, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 95.36, max: 389)
#
# Run: 311, exploration: 0.01, score: 126
# Scores: (min: 10, avg: 96.26, max: 389)
#
# Run: 312, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 95.06, max: 389)
#
# Run: 313, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 95.95, max: 389)
#
# Run: 314, exploration: 0.01, score: 111
# Scores: (min: 10, avg: 95.71, max: 389)
#
# Run: 315, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 96.03, max: 389)
#
# Run: 316, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 97, max: 389)
#
# Run: 317, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 97.3, max: 389)
#
# Run: 318, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 96.12, max: 389)
#
# Run: 319, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 95.35, max: 389)
#
# Run: 320, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 94.29, max: 389)
#
# Run: 321, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 93.53, max: 389)
#
# Run: 322, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 93.09, max: 389)
#
# Run: 323, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 93.36, max: 389)
#
# Run: 324, exploration: 0.01, score: 45
# Scores: (min: 10, avg: 93.04, max: 389)
#
# Run: 325, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 92.72, max: 389)
#
# Run: 326, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 93.11, max: 389)
#
# Run: 327, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 93.77, max: 389)
#
# Run: 328, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 94.57, max: 389)
#
# Run: 329, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 95.88, max: 389)
#
# Run: 330, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 95.97, max: 389)
#
# Run: 331, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 95.22, max: 389)
#
# Run: 332, exploration: 0.01, score: 59
# Scores: (min: 10, avg: 93.56, max: 389)
#
# Run: 333, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 92.86, max: 389)
#
# Run: 334, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 91.35, max: 389)
#
# Run: 335, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 90.6, max: 389)
#
# Run: 336, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 89.01, max: 389)
#
# Run: 337, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 86.27, max: 389)
#
# Run: 338, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 86.27, max: 389)
#
# Run: 339, exploration: 0.01, score: 438
# Scores: (min: 10, avg: 90.49, max: 438)
#
# Run: 340, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 91.39, max: 438)
#
# Run: 341, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 91.43, max: 438)
#
# Run: 342, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 90.63, max: 438)
#
# Run: 343, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 90.59, max: 438)
#
# Run: 344, exploration: 0.01, score: 91
# Scores: (min: 10, avg: 91.28, max: 438)
#
# Run: 345, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 92.09, max: 438)
#
# Run: 346, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 92.3, max: 438)
#
# Run: 347, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 93.08, max: 438)
#
# Run: 348, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 93.11, max: 438)
#
# Run: 349, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 93.06, max: 438)
#
# Run: 350, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 93.15, max: 438)
#
# Run: 351, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 93.34, max: 438)
#
# Run: 352, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 93.71, max: 438)
#
# Run: 353, exploration: 0.01, score: 61
# Scores: (min: 10, avg: 93.17, max: 438)
#
# Run: 354, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 93.3, max: 438)
#
# Run: 355, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 93.65, max: 438)
#
# Run: 356, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 92.8, max: 438)
#
# Run: 357, exploration: 0.01, score: 60
# Scores: (min: 10, avg: 92.69, max: 438)
#
# Run: 358, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 92.79, max: 438)
#
# Run: 359, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 92.38, max: 438)
#
# Run: 360, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 91.02, max: 438)
#
# Run: 361, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 88.27, max: 438)
#
# Run: 362, exploration: 0.01, score: 49
# Scores: (min: 10, avg: 87.88, max: 438)
#
# Run: 363, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 88.43, max: 438)
#
# Run: 364, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 89.72, max: 438)
#
# Run: 365, exploration: 0.01, score: 74
# Scores: (min: 10, avg: 90.19, max: 438)
#
# Run: 366, exploration: 0.01, score: 84
# Scores: (min: 10, avg: 90.33, max: 438)
#
# Run: 367, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 88.12, max: 438)
#
# Run: 368, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 87.06, max: 438)
#
# Run: 369, exploration: 0.01, score: 68
# Scores: (min: 10, avg: 87.36, max: 438)
#
# Run: 370, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 87.57, max: 438)
#
# Run: 371, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 86.46, max: 438)
#
# Run: 372, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 85.92, max: 438)
#
# Run: 373, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 86.21, max: 438)
#
# Run: 374, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 85.44, max: 438)
#
# Run: 375, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 86.59, max: 438)
#
# Run: 376, exploration: 0.01, score: 72
# Scores: (min: 10, avg: 86.66, max: 438)
#
# Run: 377, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 87.95, max: 438)
#
# Run: 378, exploration: 0.01, score: 223
# Scores: (min: 10, avg: 89.79, max: 438)
#
# Run: 379, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 90.44, max: 438)
#
# Run: 380, exploration: 0.01, score: 106
# Scores: (min: 10, avg: 91.37, max: 438)
#
# Run: 381, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 90.76, max: 438)
#
# Run: 382, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 90.24, max: 438)
#
# Run: 383, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 89.44, max: 438)
#
# Run: 384, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 89.21, max: 438)
#
# Run: 385, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 88.55, max: 438)
#
# Run: 386, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 88.17, max: 438)
#
# Run: 387, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 88.37, max: 438)
#
# Run: 388, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 88.35, max: 438)
#
# Run: 389, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 86.73, max: 438)
#
# Run: 390, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 84.99, max: 438)
#
# Run: 391, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 84.19, max: 438)
#
# Run: 392, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 82.34, max: 438)
#
# Run: 393, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 82.08, max: 438)
#
# Run: 394, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 80.05, max: 438)
#
# Run: 395, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 79.78, max: 438)
#
# Run: 396, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 79.69, max: 438)
#
# Run: 397, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 79.37, max: 438)
#
# Run: 398, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 77.79, max: 438)
#
# Run: 399, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 76.39, max: 438)
#
# Run: 400, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 77.16, max: 438)
#
# Run: 401, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 77.91, max: 438)
#
# Run: 402, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 78.88, max: 438)
#
# Run: 403, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 79.17, max: 438)
#
# Run: 404, exploration: 0.01, score: 323
# Scores: (min: 10, avg: 81.09, max: 438)
#
# Run: 405, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 81.82, max: 438)
#
# Run: 406, exploration: 0.01, score: 434
# Scores: (min: 10, avg: 85.15, max: 438)
#
# Run: 407, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 85.35, max: 438)
#
# Run: 408, exploration: 0.01, score: 236
# Scores: (min: 10, avg: 86.35, max: 438)
#
# Run: 409, exploration: 0.01, score: 45
# Scores: (min: 10, avg: 84.39, max: 438)
#
# Run: 410, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 83.61, max: 438)
#
# Run: 411, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 83.36, max: 438)
#
# Run: 412, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 83.27, max: 438)
#
# Run: 413, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 83.68, max: 438)
#
# Run: 414, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 82.97, max: 438)
#
# Run: 415, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 82.31, max: 438)
#
# Run: 416, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 81.74, max: 438)
#
# Run: 417, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 82.52, max: 438)
#
# Run: 418, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 83.74, max: 438)
#
# Run: 419, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 83.96, max: 438)
#
# Run: 420, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 84.05, max: 438)
#
# Run: 421, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 83.88, max: 438)
#
# Run: 422, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 83.81, max: 438)
#
# Run: 423, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 83.86, max: 438)
#
# Run: 424, exploration: 0.01, score: 85
# Scores: (min: 10, avg: 84.26, max: 438)
#
# Run: 425, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 84.87, max: 438)
#
# Run: 426, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 84.77, max: 438)
#
# Run: 427, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 84.36, max: 438)
#
# Run: 428, exploration: 0.01, score: 74
# Scores: (min: 10, avg: 83.89, max: 438)
#
# Run: 429, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 82.82, max: 438)
#
# Run: 430, exploration: 0.01, score: 317
# Scores: (min: 10, avg: 84.66, max: 438)
#
# Run: 431, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 85.4, max: 438)
#
# Run: 432, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 85.04, max: 438)
#
# Run: 433, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 86.36, max: 438)
#
# Run: 434, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 86.67, max: 438)
#
# Run: 435, exploration: 0.01, score: 54
# Scores: (min: 10, avg: 87.06, max: 438)
#
# Run: 436, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 88.8, max: 438)
#
# Run: 437, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 89.97, max: 438)
#
# Run: 438, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 91.79, max: 438)
#
# Run: 439, exploration: 0.01, score: 30
# Scores: (min: 11, avg: 87.71, max: 434)
#
# Run: 440, exploration: 0.01, score: 20
# Scores: (min: 11, avg: 86.82, max: 434)
#
# Run: 441, exploration: 0.01, score: 89
# Scores: (min: 11, avg: 86.59, max: 434)
#
# Run: 442, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 88.08, max: 434)
#
# Run: 443, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 87.81, max: 434)
#
# Run: 444, exploration: 0.01, score: 126
# Scores: (min: 11, avg: 88.16, max: 434)
#
# Run: 445, exploration: 0.01, score: 107
# Scores: (min: 11, avg: 88.29, max: 434)
#
# Run: 446, exploration: 0.01, score: 79
# Scores: (min: 11, avg: 88.03, max: 434)
#
# Run: 447, exploration: 0.01, score: 86
# Scores: (min: 11, avg: 87.96, max: 434)
#
# Run: 448, exploration: 0.01, score: 54
# Scores: (min: 11, avg: 88.29, max: 434)
#
# Run: 449, exploration: 0.01, score: 175
# Scores: (min: 11, avg: 89.4, max: 434)
#
# Run: 450, exploration: 0.01, score: 52
# Scores: (min: 11, avg: 89.72, max: 434)
#
# Run: 451, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 90.66, max: 434)
#
# Run: 452, exploration: 0.01, score: 282
# Scores: (min: 11, avg: 92.1, max: 434)
#
# Run: 453, exploration: 0.01, score: 437
# Scores: (min: 11, avg: 95.86, max: 437)
#
# Run: 454, exploration: 0.01, score: 19
# Scores: (min: 11, avg: 95.15, max: 437)
#
# Run: 455, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 95.5, max: 437)
#
# Run: 456, exploration: 0.01, score: 183
# Scores: (min: 11, avg: 96.36, max: 437)
#
# Run: 457, exploration: 0.01, score: 47
# Scores: (min: 11, avg: 96.23, max: 437)
#
# Run: 458, exploration: 0.01, score: 86
# Scores: (min: 11, avg: 96.88, max: 437)
#
# Run: 459, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 97.55, max: 437)
#
# Run: 460, exploration: 0.01, score: 55
# Scores: (min: 11, avg: 97.9, max: 437)
#
# Run: 461, exploration: 0.01, score: 43
# Scores: (min: 11, avg: 97.19, max: 437)
#
# Run: 462, exploration: 0.01, score: 15
# Scores: (min: 11, avg: 96.85, max: 437)
#
# Run: 463, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 96.7, max: 437)
#
# Run: 464, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 95.3, max: 437)
#
# Run: 465, exploration: 0.01, score: 89
# Scores: (min: 10, avg: 95.45, max: 437)
#
# Run: 466, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 94.72, max: 437)
#
# Run: 467, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 93.89, max: 437)
#
# Run: 468, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 93.99, max: 437)
#
# Run: 469, exploration: 0.01, score: 60
# Scores: (min: 10, avg: 93.91, max: 437)
#
# Run: 470, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 92.7, max: 437)
#
# Run: 471, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 91.66, max: 437)
#
# Run: 472, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 91.66, max: 437)
#
# Run: 473, exploration: 0.01, score: 80
# Scores: (min: 10, avg: 91.77, max: 437)
#
# Run: 474, exploration: 0.01, score: 34
# Scores: (min: 10, avg: 91.98, max: 437)
#
# Run: 475, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 90.42, max: 437)
#
# Run: 476, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 90.17, max: 437)
#
# Run: 477, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 88.66, max: 437)
#
# Run: 478, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 86.78, max: 437)
#
# Run: 479, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 86.02, max: 437)
#
# Run: 480, exploration: 0.01, score: 59
# Scores: (min: 10, avg: 85.55, max: 437)
#
# Run: 481, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 86.02, max: 437)
#
# Run: 482, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 87, max: 437)
#
# Run: 483, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 89.05, max: 437)
#
# Run: 484, exploration: 0.01, score: 65
# Scores: (min: 10, avg: 88.6, max: 437)
#
# Run: 485, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 89.18, max: 437)
#
# Run: 486, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 90.07, max: 437)
#
# Run: 487, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 89.97, max: 437)
#
# Run: 488, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 90.12, max: 437)
#
# Run: 489, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 90.05, max: 437)
#
# Run: 490, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 90.22, max: 437)
#
# Run: 491, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 90.23, max: 437)
#
# Run: 492, exploration: 0.01, score: 76
# Scores: (min: 10, avg: 90.87, max: 437)
#
# Run: 493, exploration: 0.01, score: 49
# Scores: (min: 10, avg: 91.24, max: 437)
#
# Run: 494, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 91.33, max: 437)
#
# Run: 495, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 93.02, max: 437)
#
# Run: 496, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 94.25, max: 437)
#
# Run: 497, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 95.14, max: 437)
#
# Run: 498, exploration: 0.01, score: 272
# Scores: (min: 10, avg: 97.74, max: 437)
#
# Run: 499, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 98.52, max: 437)
#
# Run: 500, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 97.71, max: 437)

# %%
# Experiment 3: Adjusting Learning Rate
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  

from scores.score_logger import ScoreLogger  

ENV_NAME = "CartPole-v1"

# Parameters (Baseline values except for LEARNING_RATE)
GAMMA = 0.95  # Baseline discount factor
LEARNING_RATE = 0.01  # Increased learning rate for faster learning

MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  

# Exploration Parameters (Baseline values)
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  

class DQNSolver:  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  

        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  

    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  

    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  

    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  

def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  # No max_runs, as in the base code
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()  

cartpole()
# Out:
# Run: 1, exploration: 0.9416228069143757, score: 32
# Scores: (min: 32, avg: 32, max: 32)
#
# Run: 2, exploration: 0.8647077305675338, score: 18
# Scores: (min: 18, avg: 25, max: 32)
#
# Run: 3, exploration: 0.8224322824348486, score: 11
# Scores: (min: 11, avg: 20.333333333333332, max: 32)
#
# Run: 4, exploration: 0.7477194593032545, score: 20
# Scores: (min: 11, avg: 20.25, max: 32)
#
# Run: 5, exploration: 0.7111635524897149, score: 11
# Scores: (min: 11, avg: 18.4, max: 32)
#
# Run: 6, exploration: 0.5967292370047992, score: 36
# Scores: (min: 11, avg: 21.333333333333332, max: 36)
#
# Run: 7, exploration: 0.567555222460375, score: 11
# Scores: (min: 11, avg: 19.857142857142858, max: 36)
#
# Run: 8, exploration: 0.531750826943791, score: 14
# Scores: (min: 11, avg: 19.125, max: 36)
#
# Run: 9, exploration: 0.5032248303978422, score: 12
# Scores: (min: 11, avg: 18.333333333333332, max: 36)
#
# Run: 10, exploration: 0.47622912292284103, score: 12
# Scores: (min: 11, avg: 17.7, max: 36)
#
# Run: 11, exploration: 0.45522245551230495, score: 10
# Scores: (min: 10, avg: 17, max: 36)
#
# Run: 12, exploration: 0.42437208406280985, score: 15
# Scores: (min: 10, avg: 16.833333333333332, max: 36)
#
# Run: 13, exploration: 0.40565285250151817, score: 10
# Scores: (min: 10, avg: 16.307692307692307, max: 36)
#
# Run: 14, exploration: 0.37816180712868996, score: 15
# Scores: (min: 10, avg: 16.214285714285715, max: 36)
#
# Run: 15, exploration: 0.3578751580867638, score: 12
# Scores: (min: 10, avg: 15.933333333333334, max: 36)
#
# Run: 16, exploration: 0.32864265128599696, score: 18
# Scores: (min: 10, avg: 16.0625, max: 36)
#
# Run: 17, exploration: 0.3017979588795719, score: 18
# Scores: (min: 10, avg: 16.176470588235293, max: 36)
#
# Run: 18, exploration: 0.28704309604425327, score: 11
# Scores: (min: 10, avg: 15.88888888888889, max: 36)
#
# Run: 19, exploration: 0.2743815040481898, score: 10
# Scores: (min: 10, avg: 15.578947368421053, max: 36)
#
# Run: 20, exploration: 0.26359640222486147, score: 9
# Scores: (min: 9, avg: 15.25, max: 36)
#
# Run: 21, exploration: 0.2532352299289372, score: 9
# Scores: (min: 9, avg: 14.952380952380953, max: 36)
#
# Run: 22, exploration: 0.24206491716205145, score: 10
# Scores: (min: 9, avg: 14.727272727272727, max: 36)
#
# Run: 23, exploration: 0.23255008201124722, score: 9
# Scores: (min: 9, avg: 14.478260869565217, max: 36)
#
# Run: 24, exploration: 0.22007483514733558, score: 12
# Scores: (min: 9, avg: 14.375, max: 36)
#
# Run: 25, exploration: 0.20619134658263935, score: 14
# Scores: (min: 9, avg: 14.36, max: 36)
#
# Run: 26, exploration: 0.19415447453059972, score: 13
# Scores: (min: 9, avg: 14.307692307692308, max: 36)
#
# Run: 27, exploration: 0.182820281282489, score: 13
# Scores: (min: 9, avg: 14.25925925925926, max: 36)
#
# Run: 28, exploration: 0.17475600159032884, score: 10
# Scores: (min: 9, avg: 14.107142857142858, max: 36)
#
# Run: 29, exploration: 0.16873052768933355, score: 8
# Scores: (min: 8, avg: 13.89655172413793, max: 36)
#
# Run: 30, exploration: 0.16209824418995536, score: 9
# Scores: (min: 8, avg: 13.733333333333333, max: 36)
#
# Run: 31, exploration: 0.1557266555690826, score: 9
# Scores: (min: 8, avg: 13.580645161290322, max: 36)
#
# Run: 32, exploration: 0.14885748713096328, score: 10
# Scores: (min: 8, avg: 13.46875, max: 36)
#
# Run: 33, exploration: 0.14087196468590776, score: 12
# Scores: (min: 8, avg: 13.424242424242424, max: 36)
#
# Run: 34, exploration: 0.1353347165085562, score: 9
# Scores: (min: 8, avg: 13.294117647058824, max: 36)
#
# Run: 35, exploration: 0.12807462877562611, score: 12
# Scores: (min: 8, avg: 13.257142857142858, max: 36)
#
# Run: 36, exploration: 0.12181307688414106, score: 11
# Scores: (min: 8, avg: 13.194444444444445, max: 36)
#
# Run: 37, exploration: 0.11643985070121858, score: 10
# Scores: (min: 8, avg: 13.108108108108109, max: 36)
#
# Run: 38, exploration: 0.11186295456362313, score: 9
# Scores: (min: 8, avg: 13, max: 36)
#
# Run: 39, exploration: 0.10692863247165257, score: 10
# Scores: (min: 8, avg: 12.923076923076923, max: 36)
#
# Run: 40, exploration: 0.10221196540767843, score: 10
# Scores: (min: 8, avg: 12.85, max: 36)
#
# Run: 41, exploration: 0.09770335251664321, score: 10
# Scores: (min: 8, avg: 12.78048780487805, max: 36)
#
# Run: 42, exploration: 0.09386293109673778, score: 9
# Scores: (min: 8, avg: 12.69047619047619, max: 36)
#
# Run: 43, exploration: 0.09017346495423652, score: 9
# Scores: (min: 8, avg: 12.604651162790697, max: 36)
#
# Run: 44, exploration: 0.08706434220766679, score: 8
# Scores: (min: 8, avg: 12.5, max: 36)
#
# Run: 45, exploration: 0.08280777787605056, score: 11
# Scores: (min: 8, avg: 12.466666666666667, max: 36)
#
# Run: 46, exploration: 0.07955285615946175, score: 9
# Scores: (min: 8, avg: 12.391304347826088, max: 36)
#
# Run: 47, exploration: 0.07680992513462537, score: 8
# Scores: (min: 8, avg: 12.297872340425531, max: 36)
#
# Run: 48, exploration: 0.07342180695061275, score: 10
# Scores: (min: 8, avg: 12.25, max: 36)
#
# Run: 49, exploration: 0.07018314008827135, score: 10
# Scores: (min: 8, avg: 12.204081632653061, max: 36)
#
# Run: 50, exploration: 0.0677632708131484, score: 8
# Scores: (min: 8, avg: 12.12, max: 36)
#
# Run: 51, exploration: 0.06542683706543727, score: 8
# Scores: (min: 8, avg: 12.03921568627451, max: 36)
#
# Run: 52, exploration: 0.06285510723190912, score: 9
# Scores: (min: 8, avg: 11.98076923076923, max: 36)
#
# Run: 53, exploration: 0.06038446427088321, score: 9
# Scores: (min: 8, avg: 11.924528301886792, max: 36)
#
# Run: 54, exploration: 0.05772088009124167, score: 10
# Scores: (min: 8, avg: 11.88888888888889, max: 36)
#
# Run: 55, exploration: 0.05517478773284426, score: 10
# Scores: (min: 8, avg: 11.854545454545455, max: 36)
#
# Run: 56, exploration: 0.05066791621302729, score: 18
# Scores: (min: 8, avg: 11.964285714285714, max: 36)
#
# Run: 57, exploration: 0.04867631463831842, score: 9
# Scores: (min: 8, avg: 11.912280701754385, max: 36)
#
# Run: 58, exploration: 0.046296535966244, score: 11
# Scores: (min: 8, avg: 11.89655172413793, max: 36)
#
# Run: 59, exploration: 0.04447676004441063, score: 9
# Scores: (min: 8, avg: 11.847457627118644, max: 36)
#
# Run: 60, exploration: 0.04272851397543923, score: 9
# Scores: (min: 8, avg: 11.8, max: 36)
#
# Run: 61, exploration: 0.04084374120782771, score: 10
# Scores: (min: 8, avg: 11.770491803278688, max: 36)
#
# Run: 62, exploration: 0.0386526615487428, score: 12
# Scores: (min: 8, avg: 11.774193548387096, max: 36)
#
# Run: 63, exploration: 0.037319942779450235, score: 8
# Scores: (min: 8, avg: 11.714285714285714, max: 36)
#
# Run: 64, exploration: 0.034271518052411715, score: 18
# Scores: (min: 8, avg: 11.8125, max: 36)
#
# Run: 65, exploration: 0.032924408985721944, score: 9
# Scores: (min: 8, avg: 11.76923076923077, max: 36)
#
# Run: 66, exploration: 0.03131473892591842, score: 11
# Scores: (min: 8, avg: 11.757575757575758, max: 36)
#
# Run: 67, exploration: 0.029933432588273214, score: 10
# Scores: (min: 8, avg: 11.73134328358209, max: 36)
#
# Run: 68, exploration: 0.028469990974320916, score: 11
# Scores: (min: 8, avg: 11.720588235294118, max: 36)
#
# Run: 69, exploration: 0.027350922279685573, score: 9
# Scores: (min: 8, avg: 11.681159420289855, max: 36)
#
# Run: 70, exploration: 0.026144461565619025, score: 10
# Scores: (min: 8, avg: 11.657142857142857, max: 36)
#
# Run: 71, exploration: 0.024991218342344988, score: 10
# Scores: (min: 8, avg: 11.633802816901408, max: 36)
#
# Run: 72, exploration: 0.023888845163905856, score: 10
# Scores: (min: 8, avg: 11.61111111111111, max: 36)
#
# Run: 73, exploration: 0.022835098131175, score: 10
# Scores: (min: 8, avg: 11.58904109589041, max: 36)
#
# Run: 74, exploration: 0.021827832324362372, score: 10
# Scores: (min: 8, avg: 11.567567567567568, max: 36)
#
# Run: 75, exploration: 0.020969846670345987, score: 9
# Scores: (min: 8, avg: 11.533333333333333, max: 36)
#
# Run: 76, exploration: 0.020145585821044927, score: 9
# Scores: (min: 8, avg: 11.5, max: 36)
#
# Run: 77, exploration: 0.019256955536244666, score: 10
# Scores: (min: 8, avg: 11.480519480519481, max: 36)
#
# Run: 78, exploration: 0.018500023224111744, score: 9
# Scores: (min: 8, avg: 11.448717948717949, max: 36)
#
# Run: 79, exploration: 0.017772843617388175, score: 9
# Scores: (min: 8, avg: 11.417721518987342, max: 36)
#
# Run: 80, exploration: 0.017160047465104442, score: 8
# Scores: (min: 8, avg: 11.375, max: 36)
#
# Run: 81, exploration: 0.0164031105360144, score: 10
# Scores: (min: 8, avg: 11.358024691358025, max: 36)
#
# Run: 82, exploration: 0.01567956241402325, score: 10
# Scores: (min: 8, avg: 11.341463414634147, max: 36)
#
# Run: 83, exploration: 0.01506324653745902, score: 9
# Scores: (min: 8, avg: 11.313253012048193, max: 36)
#
# Run: 84, exploration: 0.014398800381387675, score: 10
# Scores: (min: 8, avg: 11.297619047619047, max: 36)
#
# Run: 85, exploration: 0.013902339057518077, score: 8
# Scores: (min: 8, avg: 11.258823529411766, max: 36)
#
# Run: 86, exploration: 0.013289101019874787, score: 10
# Scores: (min: 8, avg: 11.244186046511627, max: 36)
#
# Run: 87, exploration: 0.012766746905164949, score: 9
# Scores: (min: 8, avg: 11.218390804597702, max: 36)
#
# Run: 88, exploration: 0.012264924940880204, score: 9
# Scores: (min: 8, avg: 11.193181818181818, max: 36)
#
# Run: 89, exploration: 0.01166529436067347, score: 11
# Scores: (min: 8, avg: 11.191011235955056, max: 36)
#
# Run: 90, exploration: 0.011150733307840981, score: 10
# Scores: (min: 8, avg: 11.177777777777777, max: 36)
#
# Run: 91, exploration: 0.010552547534153616, score: 12
# Scores: (min: 8, avg: 11.186813186813186, max: 36)
#
# Run: 92, exploration: 0.010087070213020206, score: 10
# Scores: (min: 8, avg: 11.173913043478262, max: 36)
#
# Run: 93, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.13978494623656, max: 36)
#
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.127659574468085, max: 36)
#
# Run: 95, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.115789473684211, max: 36)
#
# Run: 96, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.09375, max: 36)
#
# Run: 97, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.092783505154639, max: 36)
#
# Run: 98, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.091836734693878, max: 36)
#
# Run: 99, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.090909090909092, max: 36)
#
# Run: 100, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.08, max: 36)
#
# Run: 101, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.86, max: 36)
#
# Run: 102, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.79, max: 36)
#
# Run: 103, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.77, max: 36)
#
# Run: 104, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.7, max: 36)
#
# Run: 105, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.69, max: 36)
#
# Run: 106, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.45, max: 18)
#
# Run: 107, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.47, max: 18)
#
# Run: 108, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.48, max: 18)
#
# Run: 109, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.45, max: 18)
#
# Run: 110, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.46, max: 18)
#
# Run: 111, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.47, max: 18)
#
# Run: 112, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.45, max: 18)
#
# Run: 113, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.53, max: 18)
#
# Run: 114, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 10.57, max: 19)
#
# Run: 115, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 10.75, max: 30)
#
# Run: 116, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 10.84, max: 30)
#
# Run: 117, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 10.9, max: 30)
#
# Run: 118, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 10.99, max: 30)
#
# Run: 119, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 11.23, max: 34)
#
# Run: 120, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 11.65, max: 51)
#
# Run: 121, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 12.19, max: 63)
#
# Run: 122, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 12.91, max: 82)
#
# Run: 123, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 13.46, max: 82)
#
# Run: 124, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 13.63, max: 82)
#
# Run: 125, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 14.38, max: 89)
#
# Run: 126, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 15.34, max: 109)
#
# Run: 127, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.45, max: 109)
#
# Run: 128, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 15.68, max: 109)
#
# Run: 129, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 15.88, max: 109)
#
# Run: 130, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 16.41, max: 109)
#
# Run: 131, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.46, max: 109)
#
# Run: 132, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 16.66, max: 109)
#
# Run: 133, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 17.15, max: 109)
#
# Run: 134, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 17.37, max: 109)
#
# Run: 135, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 17.48, max: 109)
#
# Run: 136, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.67, max: 109)
#
# Run: 137, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 17.8, max: 109)
#
# Run: 138, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.81, max: 109)
#
# Run: 139, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.8, max: 109)
#
# Run: 140, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 17.78, max: 109)
#
# Run: 141, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.79, max: 109)
#
# Run: 142, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.81, max: 109)
#
# Run: 143, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 18.13, max: 109)
#
# Run: 144, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 18.28, max: 109)
#
# Run: 145, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 18.43, max: 109)
#
# Run: 146, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 18.71, max: 109)
#
# Run: 147, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 18.79, max: 109)
#
# Run: 148, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 18.92, max: 109)
#
# Run: 149, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 19.12, max: 109)
#
# Run: 150, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.21, max: 109)
#
# Run: 151, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19.33, max: 109)
#
# Run: 152, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 19.54, max: 109)
#
# Run: 153, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 19.73, max: 109)
#
# Run: 154, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 20.1, max: 109)
#
# Run: 155, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 20.22, max: 109)
#
# Run: 156, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.24, max: 109)
#
# Run: 157, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 20.7, max: 109)
#
# Run: 158, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 21.26, max: 109)
#
# Run: 159, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 21.54, max: 109)
#
# Run: 160, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 21.74, max: 109)
#
# Run: 161, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 22.23, max: 109)
#
# Run: 162, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 22.64, max: 109)
#
# Run: 163, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 22.82, max: 109)
#
# Run: 164, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 22.94, max: 109)
#
# Run: 165, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 23, max: 109)
#
# Run: 166, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23, max: 109)
#
# Run: 167, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 23.05, max: 109)
#
# Run: 168, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 23.17, max: 109)
#
# Run: 169, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 23.34, max: 109)
#
# Run: 170, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 23.39, max: 109)
#
# Run: 171, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 23.49, max: 109)
#
# Run: 172, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.56, max: 109)
#
# Run: 173, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.77, max: 109)
#
# Run: 174, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 24.34, max: 109)
#
# Run: 175, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 25.24, max: 109)
#
# Run: 176, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 25.34, max: 109)
#
# Run: 177, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 25.49, max: 109)
#
# Run: 178, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 25.82, max: 109)
#
# Run: 179, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 25.93, max: 109)
#
# Run: 180, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 26.43, max: 109)
#
# Run: 181, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 26.51, max: 109)
#
# Run: 182, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 26.6, max: 109)
#
# Run: 183, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 27.54, max: 109)
#
# Run: 184, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 28.14, max: 109)
#
# Run: 185, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.15, max: 109)
#
# Run: 186, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.14, max: 109)
#
# Run: 187, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.14, max: 109)
#
# Run: 188, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.14, max: 109)
#
# Run: 189, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.12, max: 109)
#
# Run: 190, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.12, max: 109)
#
# Run: 191, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.09, max: 109)
#
# Run: 192, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.08, max: 109)
#
# Run: 193, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.09, max: 109)
#
# Run: 194, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.09, max: 109)
#
# Run: 195, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.08, max: 109)
#
# Run: 196, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.09, max: 109)
#
# Run: 197, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.08, max: 109)
#
# Run: 198, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.06, max: 109)
#
# Run: 199, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.05, max: 109)
#
# Run: 200, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.03, max: 109)
#
# Run: 201, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.03, max: 109)
#
# Run: 202, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.01, max: 109)
#
# Run: 203, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.02, max: 109)
#
# Run: 204, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.98, max: 109)
#
# Run: 205, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.97, max: 109)
#
# Run: 206, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.95, max: 109)
#
# Run: 207, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.91, max: 109)
#
# Run: 208, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.86, max: 109)
#
# Run: 209, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.86, max: 109)
#
# Run: 210, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.83, max: 109)
#
# Run: 211, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.81, max: 109)
#
# Run: 212, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.78, max: 109)
#
# Run: 213, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.7, max: 109)
#
# Run: 214, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 27.62, max: 109)
#
# Run: 215, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.42, max: 109)
#
# Run: 216, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 27.26, max: 109)
#
# Run: 217, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.11, max: 109)
#
# Run: 218, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 27.04, max: 109)
#
# Run: 219, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 26.84, max: 109)
#
# Run: 220, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 26.63, max: 109)
#
# Run: 221, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 26.32, max: 109)
#
# Run: 222, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 25.67, max: 109)
#
# Run: 223, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 25.14, max: 109)
#
# Run: 224, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 25.04, max: 109)
#
# Run: 225, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 24.26, max: 109)
#
# Run: 226, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.34, max: 103)
#
# Run: 227, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 23.26, max: 103)
#
# Run: 228, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 23.07, max: 103)
#
# Run: 229, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.87, max: 103)
#
# Run: 230, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 22.4, max: 103)
#
# Run: 231, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.37, max: 103)
#
# Run: 232, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 22.35, max: 103)
#
# Run: 233, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 21.88, max: 103)
#
# Run: 234, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 21.74, max: 103)
#
# Run: 235, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 21.63, max: 103)
#
# Run: 236, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 21.49, max: 103)
#
# Run: 237, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.36, max: 103)
#
# Run: 238, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21.44, max: 103)
#
# Run: 239, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 21.49, max: 103)
#
# Run: 240, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 21.53, max: 103)
#
# Run: 241, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 21.56, max: 103)
#
# Run: 242, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 21.62, max: 103)
#
# Run: 243, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21.39, max: 103)
#
# Run: 244, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 21.37, max: 103)
#
# Run: 245, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 21.38, max: 103)
#
# Run: 246, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 21.25, max: 103)
#
# Run: 247, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 21.24, max: 103)
#
# Run: 248, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 21.2, max: 103)
#
# Run: 249, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 21.16, max: 103)
#
# Run: 250, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 21.13, max: 103)
#
# Run: 251, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21.04, max: 103)
#
# Run: 252, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.86, max: 103)
#
# Run: 253, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 20.75, max: 103)
#
# Run: 254, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.43, max: 103)
#
# Run: 255, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.36, max: 103)
#
# Run: 256, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 20.33, max: 103)
#
# Run: 257, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.96, max: 103)
#
# Run: 258, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.53, max: 103)
#
# Run: 259, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.34, max: 103)
#
# Run: 260, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.13, max: 103)
#
# Run: 261, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.64, max: 103)
#
# Run: 262, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.2, max: 103)
#
# Run: 263, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 18.42, max: 103)
#
# Run: 264, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 18.34, max: 103)
#
# Run: 265, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 18.39, max: 103)
#
# Run: 266, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.42, max: 103)
#
# Run: 267, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.45, max: 103)
#
# Run: 268, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 18.43, max: 103)
#
# Run: 269, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.35, max: 103)
#
# Run: 270, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.38, max: 103)
#
# Run: 271, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.33, max: 103)
#
# Run: 272, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 18.32, max: 103)
#
# Run: 273, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.15, max: 103)
#
# Run: 274, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.62, max: 103)
#
# Run: 275, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.78, max: 103)
#
# Run: 276, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.76, max: 103)
#
# Run: 277, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.65, max: 103)
#
# Run: 278, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.43, max: 103)
#
# Run: 279, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.41, max: 103)
#
# Run: 280, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.03, max: 103)
#
# Run: 281, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.95, max: 103)
#
# Run: 282, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.95, max: 103)
#
# Run: 283, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 15.3, max: 70)
#
# Run: 284, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.74, max: 48)
#
# Run: 285, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 14.87, max: 48)
#
# Run: 286, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.93, max: 48)
#
# Run: 287, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.04, max: 48)
#
# Run: 288, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.13, max: 48)
#
# Run: 289, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.22, max: 48)
#
# Run: 290, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.32, max: 48)
#
# Run: 291, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.37, max: 48)
#
# Run: 292, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.43, max: 48)
#
# Run: 293, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 15.69, max: 48)
#
# Run: 294, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.78, max: 48)
#
# Run: 295, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.81, max: 48)
#
# Run: 296, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.8, max: 48)
#
# Run: 297, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.85, max: 48)
#
# Run: 298, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.94, max: 48)
#
# Run: 299, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16, max: 48)
#
# Run: 300, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.04, max: 48)
#
# Run: 301, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.1, max: 48)
#
# Run: 302, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.11, max: 48)
#
# Run: 303, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.1, max: 48)
#
# Run: 304, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.12, max: 48)
#
# Run: 305, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 16.49, max: 48)
#
# Run: 306, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.63, max: 48)
#
# Run: 307, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.7, max: 48)
#
# Run: 308, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 17, max: 48)
#
# Run: 309, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.09, max: 48)
#
# Run: 310, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.17, max: 48)
#
# Run: 311, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.25, max: 48)
#
# Run: 312, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 17.42, max: 48)
#
# Run: 313, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.46, max: 48)
#
# Run: 314, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.55, max: 48)
#
# Run: 315, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.58, max: 48)
#
# Run: 316, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 17.68, max: 48)
#
# Run: 317, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.73, max: 48)
#
# Run: 318, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.77, max: 48)
#
# Run: 319, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.73, max: 48)
#
# Run: 320, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17.68, max: 48)
#
# Run: 321, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.52, max: 48)
#
# Run: 322, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17.57, max: 48)
#
# Run: 323, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.61, max: 48)
#
# Run: 324, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 17.63, max: 48)
#
# Run: 325, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.63, max: 48)
#
# Run: 326, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 17.72, max: 48)
#
# Run: 327, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 17.85, max: 48)
#
# Run: 328, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 17.97, max: 48)
#
# Run: 329, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 18.17, max: 48)
#
# Run: 330, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 18.3, max: 48)
#
# Run: 331, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.37, max: 48)
#
# Run: 332, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.39, max: 48)
#
# Run: 333, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 18.97, max: 72)
#
# Run: 334, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 19.03, max: 72)
#
# Run: 335, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.15, max: 72)
#
# Run: 336, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.15, max: 72)
#
# Run: 337, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 19.34, max: 72)
#
# Run: 338, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.31, max: 72)
#
# Run: 339, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.32, max: 72)
#
# Run: 340, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.33, max: 72)
#
# Run: 341, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 19.45, max: 72)
#
# Run: 342, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 19.62, max: 72)
#
# Run: 343, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 19.74, max: 72)
#
# Run: 344, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.68, max: 72)
#
# Run: 345, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.58, max: 72)
#
# Run: 346, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.43, max: 72)
#
# Run: 347, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.39, max: 72)
#
# Run: 348, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 19.93, max: 73)
#
# Run: 349, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.77, max: 73)
#
# Run: 350, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 20.05, max: 73)
#
# Run: 351, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 20.02, max: 73)
#
# Run: 352, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 20.3, max: 73)
#
# Run: 353, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.24, max: 73)
#
# Run: 354, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.45, max: 73)
#
# Run: 355, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.5, max: 73)
#
# Run: 356, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.49, max: 73)
#
# Run: 357, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.4, max: 73)
#
# Run: 358, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.34, max: 73)
#
# Run: 359, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 20.46, max: 73)
#
# Run: 360, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 20.78, max: 73)
#
# Run: 361, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.78, max: 73)
#
# Run: 362, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 21.41, max: 73)
#
# Run: 363, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21.04, max: 73)
#
# Run: 364, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21, max: 73)
#
# Run: 365, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.95, max: 73)
#
# Run: 366, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 21.19, max: 73)
#
# Run: 367, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 21.44, max: 73)
#
# Run: 368, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 21.65, max: 73)
#
# Run: 369, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 21.62, max: 73)
#
# Run: 370, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 21.6, max: 73)
#
# Run: 371, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21.63, max: 73)
#
# Run: 372, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 21.92, max: 73)
#
# Run: 373, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 22.42, max: 73)
#
# Run: 374, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 22.95, max: 73)
#
# Run: 375, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.91, max: 73)
#
# Run: 376, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 22.87, max: 73)
#
# Run: 377, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.83, max: 73)
#
# Run: 378, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.73, max: 73)
#
# Run: 379, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 22.85, max: 73)
#
# Run: 380, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 22.89, max: 73)
#
# Run: 381, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 23.17, max: 73)
#
# Run: 382, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 23.26, max: 73)
#
# Run: 383, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 23.39, max: 73)
#
# Run: 384, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 23.62, max: 73)
#
# Run: 385, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 24.15, max: 75)
#
# Run: 386, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 24.88, max: 88)
#
# Run: 387, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 25.21, max: 88)
#
# Run: 388, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 25.76, max: 88)
#
# Run: 389, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 26.65, max: 107)
#
# Run: 390, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 26.9, max: 107)
#
# Run: 391, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 27.42, max: 107)
#
# Run: 392, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 27.85, max: 107)
#
# Run: 393, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.59, max: 107)
#
# Run: 394, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.48, max: 107)
#
# Run: 395, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.44, max: 107)
#
# Run: 396, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.45, max: 107)
#
# Run: 397, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.39, max: 107)
#
# Run: 398, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.29, max: 107)
#
# Run: 399, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.23, max: 107)
#
# Run: 400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.2, max: 107)
#
# Run: 401, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.13, max: 107)
#
# Run: 402, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.13, max: 107)
#
# Run: 403, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.14, max: 107)
#
# Run: 404, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.12, max: 107)
#
# Run: 405, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 26.74, max: 107)
#
# Run: 406, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.6, max: 107)
#
# Run: 407, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.53, max: 107)
#
# Run: 408, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.23, max: 107)
#
# Run: 409, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.14, max: 107)
#
# Run: 410, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.06, max: 107)
#
# Run: 411, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.99, max: 107)
#
# Run: 412, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.81, max: 107)
#
# Run: 413, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 25.78, max: 107)
#
# Run: 414, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.68, max: 107)
#
# Run: 415, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.64, max: 107)
#
# Run: 416, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.51, max: 107)
#
# Run: 417, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.46, max: 107)
#
# Run: 418, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.39, max: 107)
#
# Run: 419, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.41, max: 107)
#
# Run: 420, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 25.72, max: 107)
#
# Run: 421, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.65, max: 107)
#
# Run: 422, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.53, max: 107)
#
# Run: 423, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.47, max: 107)
#
# Run: 424, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.34, max: 107)
#
# Run: 425, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.33, max: 107)
#
# Run: 426, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 25.38, max: 107)
#
# Run: 427, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 25.4, max: 107)
#
# Run: 428, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 25.82, max: 107)
#
# Run: 429, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 26.5, max: 107)
#
# Run: 430, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.32, max: 107)
#
# Run: 431, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 26.45, max: 107)
#
# Run: 432, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 26.46, max: 107)
#
# Run: 433, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 26.05, max: 107)
#
# Run: 434, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 26.02, max: 107)
#
# Run: 435, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 25.91, max: 107)
#
# Run: 436, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.87, max: 107)
#
# Run: 437, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.68, max: 107)
#
# Run: 438, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 25.67, max: 107)
#
# Run: 439, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.64, max: 107)
#
# Run: 440, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 25.64, max: 107)
#
# Run: 441, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 25.59, max: 107)
#
# Run: 442, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.37, max: 107)
#
# Run: 443, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 25.34, max: 107)
#
# Run: 444, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 25.46, max: 107)
#
# Run: 445, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 25.42, max: 107)
#
# Run: 446, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.55, max: 107)
#
# Run: 447, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 25.55, max: 107)
#
# Run: 448, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 24.97, max: 107)
#
# Run: 449, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 25.07, max: 107)
#
# Run: 450, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 24.88, max: 107)
#
# Run: 451, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 25.03, max: 107)
#
# Run: 452, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 24.87, max: 107)
#
# Run: 453, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 25.03, max: 107)
#
# Run: 454, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 24.87, max: 107)
#
# Run: 455, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 24.78, max: 107)
#
# Run: 456, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 24.76, max: 107)
#
# Run: 457, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 25, max: 107)
#
# Run: 458, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 24.96, max: 107)
#
# Run: 459, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.76, max: 107)
#
# Run: 460, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 25.21, max: 107)
#
# Run: 461, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 25.66, max: 107)
#
# Run: 462, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 25.15, max: 107)
#
# Run: 463, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 25.22, max: 107)
#
# Run: 464, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 25.32, max: 107)
#
# Run: 465, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 25.76, max: 107)
#
# Run: 466, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 25.75, max: 107)
#
# Run: 467, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 25.52, max: 107)
#
# Run: 468, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 25.94, max: 107)
#
# Run: 469, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 26.1, max: 107)
#
# Run: 470, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 26.6, max: 107)
#
# Run: 471, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 26.66, max: 107)
#
# Run: 472, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 26.83, max: 107)
#
# Run: 473, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 26.38, max: 107)
#
# Run: 474, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 25.97, max: 107)
#
# Run: 475, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 26.31, max: 107)
#
# Run: 476, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.28, max: 107)
#
# Run: 477, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.28, max: 107)
#
# Run: 478, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.28, max: 107)
#
# Run: 479, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 26.1, max: 107)
#
# Run: 480, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 26.53, max: 107)
#
# Run: 481, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 27.08, max: 107)
#
# Run: 482, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 26.94, max: 107)
#
# Run: 483, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 26.8, max: 107)
#
# Run: 484, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 26.56, max: 107)
#
# Run: 485, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.93, max: 107)
#
# Run: 486, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.15, max: 107)
#
# Run: 487, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 25.02, max: 107)
#
# Run: 488, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 24.43, max: 107)
#
# Run: 489, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 23.58, max: 96)
#
# Run: 490, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.24, max: 96)
#
# Run: 491, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 22.73, max: 96)
#
# Run: 492, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 22.45, max: 96)
#
# Run: 493, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 22.57, max: 96)
#
# Run: 494, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 22.61, max: 96)
#
# Run: 495, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.64, max: 96)
#
# Run: 496, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.64, max: 96)
#
# Run: 497, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 22.74, max: 96)
#
# Run: 498, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 22.89, max: 96)
#
# Run: 499, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 22.96, max: 96)
#
# Run: 500, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 23.3, max: 96)
#
# Run: 501, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.38, max: 96)
#
# Run: 502, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 23.4, max: 96)
#
# Run: 503, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 23.74, max: 96)
#
# Run: 504, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 23.99, max: 96)
#
# Run: 505, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 24.16, max: 96)
#
# Run: 506, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 24.17, max: 96)
#
# Run: 507, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 24.48, max: 96)
#
# Run: 508, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 25.07, max: 96)
#
# Run: 509, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 25.27, max: 96)
#
# Run: 510, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.29, max: 96)
#
# Run: 511, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.41, max: 96)
#
# Run: 512, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 25.43, max: 96)
#
# Run: 513, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 25.99, max: 96)
#
# Run: 514, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 26.56, max: 96)
#
# Run: 515, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 26.63, max: 96)
#
# Run: 516, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 27.21, max: 96)
#
# Run: 517, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.22, max: 96)
#
# Run: 518, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.2, max: 96)
#
# Run: 519, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.18, max: 96)
#
# Run: 520, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.72, max: 96)
#
# Run: 521, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.73, max: 96)
#
# Run: 522, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 26.71, max: 96)
#
# Run: 523, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.72, max: 96)
#
# Run: 524, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.74, max: 96)
#
# Run: 525, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.74, max: 96)
#
# Run: 526, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 27.6, max: 117)
#
# Run: 527, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 29.07, max: 178)
#
# Run: 528, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 28.51, max: 178)
#
# Run: 529, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 27.89, max: 178)
#
# Run: 530, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 28.57, max: 178)
#
# Run: 531, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 28.96, max: 178)
#
# Run: 532, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 29.12, max: 178)
#
# Run: 533, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 29.32, max: 178)
#
# Run: 534, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 29.52, max: 178)
#
# Run: 535, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 29.55, max: 178)
#
# Run: 536, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 29.54, max: 178)
#
# Run: 537, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 30.2, max: 178)
#
# Run: 538, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 30.4, max: 178)
#
# Run: 539, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 30.46, max: 178)
#
# Run: 540, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 30.72, max: 178)
#
# Run: 541, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 31.01, max: 178)
#
# Run: 542, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 31.08, max: 178)
#
# Run: 543, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.9, max: 178)
#
# Run: 544, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.73, max: 178)
#
# Run: 545, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.7, max: 178)
#
# Run: 546, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.56, max: 178)
#
# Run: 547, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.54, max: 178)
#
# Run: 548, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.48, max: 178)
#
# Run: 549, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.37, max: 178)
#
# Run: 550, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.23, max: 178)
#
# Run: 551, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.1, max: 178)
#
# Run: 552, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.95, max: 178)
#
# Run: 553, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.78, max: 178)
#
# Run: 554, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 29.71, max: 178)
#
# Run: 555, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 30.17, max: 178)
#
# Run: 556, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 30.39, max: 178)
#
# Run: 557, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 30.48, max: 178)
#
# Run: 558, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 31.41, max: 178)
#
# Run: 559, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 31.83, max: 178)
#
# Run: 560, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 31.22, max: 178)
#
# Run: 561, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 30.93, max: 178)
#
# Run: 562, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 30.95, max: 178)
#
# Run: 563, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 30.95, max: 178)
#
# Run: 564, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 30.79, max: 178)
#
# Run: 565, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 30.35, max: 178)
#
# Run: 566, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 30.14, max: 178)
#
# Run: 567, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 30.06, max: 178)
#
# Run: 568, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 29.41, max: 178)
#
# Run: 569, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 29.39, max: 178)
#
# Run: 570, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 28.96, max: 178)
#
# Run: 571, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 29.17, max: 178)
#
# Run: 572, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 28.66, max: 178)
#
# Run: 573, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 28.75, max: 178)
#
# Run: 574, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 28.81, max: 178)
#
# Run: 575, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 28.93, max: 178)
#
# Run: 576, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 29.19, max: 178)
#
# Run: 577, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 29.89, max: 178)
#
# Run: 578, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 30.07, max: 178)
#
# Run: 579, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 30.23, max: 178)
#
# Run: 580, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.65, max: 178)
#
# Run: 581, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 29.16, max: 178)
#
# Run: 582, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.12, max: 178)
#
# Run: 583, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 29.52, max: 178)
#
# Run: 584, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 29.91, max: 178)
#
# ...
#
# Run: 867, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.99, max: 19)
#
# Run: 868, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.01, max: 19)
#
# Run: 869, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10, max: 19)
#
# Run: 870, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10, max: 19)
#
# Run: 871, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.01, max: 19)
#
# Run: 872, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.02, max: 19)
#
# Run: 873, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.04, max: 19)
#
# Run: 874, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.08, max: 19)
#
# Run: 875, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.11, max: 19)
#
# Run: 876, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.14, max: 19)
#
# Run: 877, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.17, max: 19)
#
# Run: 878, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.21, max: 19)
#
# Run: 879, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.27, max: 19)
#
# Run: 880, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.31, max: 19)
#
# Run: 881, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.34, max: 19)
#
# Run: 882, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.35, max: 19)
#
# Run: 883, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.38, max: 19)
#
# Run: 884, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.43, max: 19)
#
# Run: 885, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.45, max: 19)
#
# Run: 886, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.45, max: 19)
#
# Run: 887, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.5, max: 19)
#
# Run: 888, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.53, max: 19)
#
# Run: 889, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.58, max: 19)
#
# Run: 890, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.66, max: 19)
#
# Run: 891, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.72, max: 19)
#
# Run: 892, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.77, max: 19)
#
# Run: 893, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.8, max: 19)
#
# Run: 894, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.8, max: 19)
#
# Run: 895, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.84, max: 19)
#
# Run: 896, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 10.9, max: 19)
#
# Run: 897, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.95, max: 19)
#
# Run: 898, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.95, max: 19)
#
# Run: 899, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11, max: 19)
#
# Run: 900, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.01, max: 19)
#
# Run: 901, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.1, max: 19)
#
# Run: 902, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.15, max: 19)
#
# Run: 903, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.17, max: 19)
#
# Run: 904, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.18, max: 19)
#
# Run: 905, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.22, max: 19)
#
# Run: 906, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.31, max: 19)
#
# Run: 907, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.36, max: 19)
#
# Run: 908, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.41, max: 19)
#
# Run: 909, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.44, max: 19)
#
# Run: 910, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.49, max: 19)
#
# Run: 911, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.53, max: 19)
#
# Run: 912, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.56, max: 19)
#
# Run: 913, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.62, max: 19)
#
# Run: 914, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.68, max: 19)
#
# Run: 915, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.73, max: 19)
#
# Run: 916, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.82, max: 19)
#
# Run: 917, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.9, max: 19)
#
# Run: 918, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 12.11, max: 31)
#
# Run: 919, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 12.49, max: 47)
#
# Run: 920, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.52, max: 47)
#
# Run: 921, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 12.68, max: 47)
#
# Run: 922, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 12.9, max: 47)
#
# Run: 923, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 13.08, max: 47)
#
# Run: 924, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 13.24, max: 47)
#
# Run: 925, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 13.81, max: 66)
#
# Run: 926, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 14.06, max: 66)
#
# Run: 927, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 14.34, max: 66)
#
# Run: 928, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 14.73, max: 66)
#
# Run: 929, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.76, max: 66)
#
# Run: 930, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.75, max: 66)
#
# Run: 931, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.73, max: 66)
#
# Run: 932, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 14.87, max: 66)
#
# Run: 933, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 15.07, max: 66)
#
# Run: 934, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 15.34, max: 66)
#
# Run: 935, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.42, max: 66)
#
# Run: 936, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 15.77, max: 66)
#
# Run: 937, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.82, max: 66)
#
# Run: 938, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.91, max: 66)
#
# Run: 939, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 16.54, max: 73)
#
# Run: 940, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.67, max: 73)
#
# Run: 941, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.76, max: 73)
#
# Run: 942, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 17.17, max: 73)
#
# Run: 943, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 17.38, max: 73)
#
# Run: 944, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 17.94, max: 73)
#
# Run: 945, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.95, max: 73)
#
# Run: 946, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 18.45, max: 73)
#
# Run: 947, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 18.84, max: 73)
#
# Run: 948, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 19.31, max: 73)
#
# Run: 949, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.38, max: 73)
#
# Run: 950, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 19.53, max: 73)
#
# Run: 951, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 19.92, max: 73)
#
# Run: 952, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 20.22, max: 73)
#
# Run: 953, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 20.73, max: 73)
#
# Run: 954, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 21.36, max: 73)
#
# Run: 955, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 22.07, max: 84)
#
# Run: 956, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 23.08, max: 111)
#
# Run: 957, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 23.93, max: 111)
#
# Run: 958, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 25.23, max: 143)
#
# Run: 959, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 25.24, max: 143)
#
# Run: 960, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 26.35, max: 143)
#
# Run: 961, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 27.34, max: 143)
#
# Run: 962, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 28.11, max: 143)
#
# Run: 963, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 28.47, max: 143)
#
# Run: 964, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 29.86, max: 152)
#
# Run: 965, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 31.05, max: 152)
#
# Run: 966, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 31.58, max: 152)
#
# Run: 967, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 32.71, max: 152)
#
# Run: 968, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 33.75, max: 152)
#
# Run: 969, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 33.85, max: 152)
#
# Run: 970, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 35.68, max: 192)
#
# Run: 971, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 36.07, max: 192)
#
# Run: 972, exploration: 0.01, score: 311
# Scores: (min: 8, avg: 39.08, max: 311)
#
# Run: 973, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 40.52, max: 311)
#
# Run: 974, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 41.5, max: 311)
#
# Run: 975, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 41.89, max: 311)
#
# Run: 976, exploration: 0.01, score: 260
# Scores: (min: 8, avg: 44.37, max: 311)
#
# Run: 977, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 45.5, max: 311)
#
# Run: 978, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 45.59, max: 311)
#
# Run: 979, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 46.26, max: 311)
#
# Run: 980, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 48.07, max: 311)
#
# Run: 981, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 48.58, max: 311)
#
# Run: 982, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 50.47, max: 311)
#
# Run: 983, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 52.04, max: 311)
#
# Run: 984, exploration: 0.01, score: 426
# Scores: (min: 8, avg: 56.16, max: 426)
#
# Run: 985, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 57.55, max: 426)
#
# Run: 986, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 57.66, max: 426)
#
# Run: 987, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 59.22, max: 426)
#
# Run: 988, exploration: 0.01, score: 273
# Scores: (min: 8, avg: 61.82, max: 426)
#
# Run: 989, exploration: 0.01, score: 387
# Scores: (min: 8, avg: 65.56, max: 426)
#
# Run: 990, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 65.86, max: 426)
#
# Run: 991, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 67.65, max: 426)
#
# Run: 992, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.6, max: 426)
#
# Run: 993, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 67.57, max: 426)
#
# Run: 994, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 67.56, max: 426)
#
# Run: 995, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.54, max: 426)
#
# Run: 996, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.48, max: 426)
#
# Run: 997, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.44, max: 426)
#
# Run: 998, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 67.42, max: 426)
#
# Run: 999, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.37, max: 426)
#
# Run: 1000, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 67.33, max: 426)
#
# Run: 1001, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 67.25, max: 426)
#
# Run: 1002, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.21, max: 426)
#
# Run: 1003, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 67.18, max: 426)
#
# Run: 1004, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 67.16, max: 426)
#
# Run: 1005, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.12, max: 426)
#
# Run: 1006, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.05, max: 426)
#
# Run: 1007, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.01, max: 426)
#
# Run: 1008, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.97, max: 426)
#
# Run: 1009, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.93, max: 426)
#
# Run: 1010, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.88, max: 426)
#
# Run: 1011, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 66.84, max: 426)
#
# Run: 1012, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.81, max: 426)
#
# Run: 1013, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 66.73, max: 426)
#
# Run: 1014, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.68, max: 426)
#
# Run: 1015, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 66.61, max: 426)
#
# Run: 1016, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 66.52, max: 426)
#
# Run: 1017, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 66.45, max: 426)
#
# Run: 1018, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 66.23, max: 426)
#
# Run: 1019, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 65.86, max: 426)
#
# Run: 1020, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 65.84, max: 426)
#
# Run: 1021, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 65.68, max: 426)
#
# Run: 1022, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 65.46, max: 426)
#
# Run: 1023, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 65.28, max: 426)
#
# Run: 1024, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 65.12, max: 426)
#
# Run: 1025, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 64.55, max: 426)
#
# Run: 1026, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 64.31, max: 426)
#
# Run: 1027, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 64.05, max: 426)
#
# Run: 1028, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 63.66, max: 426)
#
# Run: 1029, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 63.65, max: 426)
#
# Run: 1030, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 63.67, max: 426)
#
# Run: 1031, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 63.71, max: 426)
#
# Run: 1032, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 63.63, max: 426)
#
# Run: 1033, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 63.5, max: 426)
#
# Run: 1034, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 63.26, max: 426)
#
# Run: 1035, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 63.23, max: 426)
#
# Run: 1036, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 63.19, max: 426)
#
# Run: 1037, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 63.19, max: 426)
#
# Run: 1038, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 63.17, max: 426)
#
# Run: 1039, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 62.64, max: 426)
#
# Run: 1040, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 62.54, max: 426)
#
# Run: 1041, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 62.49, max: 426)
#
# Run: 1042, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 62.24, max: 426)
#
# Run: 1043, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 62.07, max: 426)
#
# Run: 1044, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 61.52, max: 426)
#
# Run: 1045, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 61.57, max: 426)
#
# Run: 1046, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 61.1, max: 426)
#
# Run: 1047, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 60.74, max: 426)
#
# Run: 1048, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 60.36, max: 426)
#
# Run: 1049, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 60.29, max: 426)
#
# Run: 1050, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 60.35, max: 426)
#
# Run: 1051, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 59.99, max: 426)
#
# Run: 1052, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 59.83, max: 426)
#
# Run: 1053, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 59.3, max: 426)
#
# Run: 1054, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 58.84, max: 426)
#
# Run: 1055, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 58.28, max: 426)
#
# Run: 1056, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 57.38, max: 426)
#
# Run: 1057, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 56.7, max: 426)
#
# Run: 1058, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 55.41, max: 426)
#
# Run: 1059, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 55.32, max: 426)
#
# Run: 1060, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 54.17, max: 426)
#
# Run: 1061, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 53.21, max: 426)
#
# Run: 1062, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 52.37, max: 426)
#
# Run: 1063, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 52.41, max: 426)
#
# Run: 1064, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 51.02, max: 426)
#
# Run: 1065, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 50.22, max: 426)
#
# Run: 1066, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 50.29, max: 426)
#
# Run: 1067, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 49.29, max: 426)
#
# Run: 1068, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 48.79, max: 426)
#
# Run: 1069, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 48.89, max: 426)

# %% [markdown]
# Analysis of CartPole Problem Using Reinforcement Learning
# 1. How Reinforcement Learning Concepts Apply to the CartPole Problem
# Reinforcement learning (RL) is a method where an agent learns to make sequential decisions through interactions with an environment to maximize cumulative rewards (Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problems, 1983). In the CartPole problem, the agent learns by trial and error how to balance a pole on a moving cart by taking actions that lead to the highest cumulative reward.
#
# 2. The Goal of the Agent
# The goal of the agent in the CartPole problem is to keep the pole balanced for as many time steps as possible. The agent receives a reward at each time step for successfully balancing the pole, with the episode ending when the pole falls over or the cart moves out of bounds.
# 3. State Values
# The state in the CartPole problem is represented by four values:
# Position of the cart.
# Velocity of the cart.
# Angle of the pole.
# Angular velocity of the pole
# These state values describe the environment's current situation, which the agent uses to decide on its next action.
# 4. Possible Actions
# The agent has two possible actions:
# Move the cart to the left.
# Move the cart to the right.
# These actions directly affect the cart's movement and the pole's stability, determining the success or failure of each episode.
# 5. Reinforcement Algorithm Used
# The algorithm used in this problem is Deep Q-Learning, which is an extension of the Q-learning algorithm. Q-learning updates the expected reward (Q-value) for each action in a given state to converge on an optimal policy (Mnih et al., 2015). The "deep" aspect involves using a neural network to approximate these Q-values for continuous state spaces.
# 6. How Experience Replay Is Applied
# Experience replay stores the agent's experiences (state, action, reward, next state) in a buffer, allowing the agent to sample random batches for training. This process breaks the temporal correlation between consecutive experiences, which improves the stability and convergence of the learning algorithm (Lin, 1992). In the CartPole problem, the agent replays random batches of experiences to update the neural network's weights.
# 7. Effect of the Discount Factor (GAMMA) on Future Rewards
# The discount factor (GAMMA) determines the importance of future rewards. A high GAMMA (close to 1) focuses on long-term gains, while a lower GAMMA emphasizes short-term rewards. In our experiment, setting GAMMA to 0.85 resulted in the agent's failure to solve the problem within 500 runs, suggesting that prioritizing immediate rewards can hinder the agent's ability to learn an effective long-term strategy.
# 8. Neural Network Architecture in Deep Q-Learning
# The neural network used in the CartPole problem is a fully connected feedforward network:
# Input layer: Takes the state values (4 nodes for the cart's position, velocity, pole's angle, and angular velocity).
# Hidden layers: Two hidden layers with 24 neurons each, using ReLU activation functions to introduce non-linearity (Glorot & Bengio, 2010).
# Output layer: Contains two neurons representing the possible actions (left and right), outputting the expected Q-values for each action (Mnih et al., 2015).
# 9. How the Neural Network Makes the Q-Learning Algorithm More Efficient
# In traditional Q-learning, the agent maintains a Q-table for all state-action pairs, which becomes impractical for environments with large or continuous state spaces. Using a neural network allows the agent to generalize across similar states, approximating Q-values for unseen states, which significantly enhances learning efficiency (Mnih et al., 2015).
# 10. Observations on the Learning Rate (LEARNING_RATE)
# The learning rate controls how much the network adjusts its weights based on new information. A higher learning rate results in quicker learning but risks instability (Glorot & Bengio, 2010). In our experiment with an increased learning rate (0.01), the agent did not solve the problem and timed out after 1,069 runs, indicating that too aggressive updates led to oscillations in the learning process.
#
# 11. Observations on the Exploration Factor
# The exploration factor encourages the agent to explore various actions to learn an effective policy. Adjusting the EXPLORATION_MIN and EXPLORATION_DECAY directly impacts the agent's exploration-exploitation trade-off. In our experiment, aggressive decay and a lower minimum exploration rate resulted in 100 runs without solving the problem, implying insufficient exploration of the environment .
#
#
# References
# Neuronlike adaptive elements that can solve difficult learning control problems. (1983, October 1). IEEE Journals & Magazine | IEEE Xplore. https://ieeexplore.ieee.org/document/6313077
#
# Glorot, X., & Bengio, Y. (2010, March 31). Understanding the difficulty of training deep feedforward neural networks. PMLR. https://proceedings.mlr.press/v9/glorot10a.html
#
# Lin, L. (1992). Self-improving reactive agents based on reinforcement learning, planning and teaching. Machine Learning, 8(3–4), 293–321. https://doi.org/10.1007/bf00992699
#
# Mnih, V., Kavukcuoglu, K., Silver, D., Rusu, A. A., Veness, J., Bellemare, M. G., Graves, A., Riedmiller, M., Fidjeland, A. K., Ostrovski, G., Petersen, S., Beattie, C., Sadik, A., Antonoglou, I., King, H., Kumaran, D., Wierstra, D., Legg, S., & Hassabis, D. (2015). Human-level control through deep reinforcement learning. Nature, 518(7540), 529–533. https://doi.org/10.1038/nature14236
